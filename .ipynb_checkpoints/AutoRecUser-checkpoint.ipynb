# %%
import pandas as pd
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
# Load dataset
ratings_path = "ml-latest-small/ratings.csv"
ratings = pd.read_csv(ratings_path)

# %%
# Identify actual min and max ratings
min_rating = ratings['rating'].min()
max_rating = ratings['rating'].max()
print(f"Min rating: {min_rating}, Max rating: {max_rating}")
# Out:
# Min rating: 0.5, Max rating: 5.0

# %%
# Normalize ratings based on actual range
ratings['normalized_rating'] = ratings['rating'].apply(
    lambda x: (x - min_rating) / (max_rating - min_rating) if x > 0 else 0
)

# %%
# Map userId and movieId to consecutive indices
user_mapping = {user_id: idx for idx, user_id in enumerate(ratings['userId'].unique())}
movie_mapping = {movie_id: idx for idx, movie_id in enumerate(ratings['movieId'].unique())}

ratings['userId'] = ratings['userId'].map(user_mapping)
ratings['movieId'] = ratings['movieId'].map(movie_mapping)

# Number of users and movies
num_users = len(user_mapping)
num_movies = len(movie_mapping)
print(f"Number of users: {num_users}")
print(f"Number of movies: {num_movies}")
# Out:
# Number of users: 610
# Number of movies: 9724

# %%
# Create user-item interaction matrix
user_item_matrix = torch.zeros((num_users, num_movies))

# Populate user-item interaction matrix
for row in ratings.itertuples():
    user_item_matrix[row.userId, row.movieId] = row.normalized_rating

# %%
user_item_matrix
# Out:
# tensor([[0.7778, 0.7778, 0.7778,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         ...,
#         [0.4444, 0.3333, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.5556, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [1.0000, 0.0000, 1.0000,  ..., 0.5556, 0.6667, 0.6667]])

# %%
# Split users into train/val and test groups
users = ratings['userId'].unique()
train_val_users, test_users = train_test_split(users, test_size=0.2, random_state=727)

# Create train/val and test dataframes based on the user split
train_val_data = ratings[ratings['userId'].isin(train_val_users)].reset_index(drop=True)
test_data = ratings[ratings['userId'].isin(test_users)].reset_index(drop=True)

print(f"Train/Val Data Size: {train_val_data.shape[0]}")
print(f"Test Data Size: {test_data.shape[0]}")
# Out:
# Train/Val Data Size: 86539
# Test Data Size: 14297

# %%
# Train/Val Matrix: Only for train_val_users
train_val_matrix = torch.zeros((len(train_val_users), num_movies))

# Test Matrix: Only for test_users
test_matrix = torch.zeros((len(test_users), num_movies))

# Populate train/val and test matrices
train_val_user_mapping = {u: i for i, u in enumerate(train_val_users)}
test_user_mapping = {u: i for i, u in enumerate(test_users)}

for row in train_val_data.itertuples():
    user_idx = train_val_user_mapping[row.userId]
    train_val_matrix[user_idx, row.movieId] = row.normalized_rating

for row in test_data.itertuples():
    user_idx = test_user_mapping[row.userId]
    test_matrix[user_idx, row.movieId] = row.normalized_rating

print("Train/Val and Test matrices populated.")
# Out:
# Train/Val and Test matrices populated.

# %%
total_entries = num_users * num_movies

non_zero_entries = ratings.shape[0]

sparsity = (1 - (non_zero_entries / total_entries)) * 100

print(f"User-Item Matrix Sparsity: {sparsity:.2f}%")
# Out:
# User-Item Matrix Sparsity: 98.30%

# %% [markdown]
# # Data augmentation
#
# Worsen's the performance, because data sparsity is 98+%

# %%
# def impute_with_item_averages(matrix):
#     # Compute average rating for each movie (ignoring zeros)
#     item_avg_ratings = torch.sum(matrix, dim=0) / (torch.sum(matrix > 0, dim=0) + 1e-8)

#     # Create a mask for missing ratings (zeros in the matrix)
#     missing_mask = matrix == 0

#     # Broadcast item_avg_ratings to the entire matrix and apply only to missing values
#     item_avg_matrix = item_avg_ratings.unsqueeze(0).expand_as(matrix)  # Expand to match matrix dimensions
#     matrix[missing_mask] = item_avg_matrix[missing_mask]  # Fill missing values with item averages

#     return matrix

# # Apply imputation to train_val_matrix and test_matrix
# train_val_matrix = impute_with_item_averages(train_val_matrix)
# test_matrix = impute_with_item_averages(test_matrix)


# # Final Matrix Shapes
# print(f"Train/Val Matrix Shape: {train_val_matrix.shape}")
# print(f"Test Matrix Shape: {test_matrix.shape}")

# %%
user_item_matrix.shape
# Out:
# torch.Size([610, 9724])

# %%
test_data
# Out:
#        userId  movieId  rating   timestamp  normalized_rating
# 0           1      232     3.0  1445714835           0.555556
# 1           1       18     4.0  1445715029           0.777778
# 2           1      233     4.5  1445715228           0.888889
# 3           1      219     4.0  1445714885           0.777778
# 4           1      234     4.0  1445714952           0.777778
# ...       ...      ...     ...         ...                ...
# 14292     601     1428     3.0   840876597           0.555556
# 14293     601       42     4.0   840876371           0.777778
# 14294     601     2426     4.0   840876188           0.777778
# 14295     601     2443     3.0   840876032           0.555556
# 14296     601     3005     4.0   840876498           0.777778
#
# [14297 rows x 5 columns]

# %%
train_matrix, val_matrix = train_test_split(train_val_matrix, test_size=0.2, random_state=78)

# %%
test_data.shape
# Out:
# (14297, 5)

# %%
train_val_matrix.shape
# Out:
# torch.Size([488, 9724])

# %%
test_matrix.shape
# Out:
# torch.Size([122, 9724])

# %%
val_matrix.shape
# Out:
# torch.Size([98, 9724])

# %%
class AutoRecSig(nn.Module):
    def __init__(self, num_items, hidden_dim, lambda_, p=0.2):
        super(AutoRecSig, self).__init__()
        self.lambda_ = lambda_
        self.encoder = nn.Linear(num_items, hidden_dim, bias=True)
        self.decoder = nn.Linear(hidden_dim, num_items, bias=True)
        self.sigmoid = nn.Sigmoid()
        self.dropout = nn.Dropout(p)

    def forward(self, x):
        encoded = self.dropout(self.sigmoid(self.encoder(x)))
        decoded = self.decoder(encoded)
        return decoded

    def regularization_loss(self):
        reg_loss = 0
        for param in self.parameters():
            reg_loss += param.norm(2)
        return self.lambda_ * reg_loss

# %%
class AutoRecTan(nn.Module):
    def __init__(self, num_items, hidden_dim, lambda_, p=0.2):
        super(AutoRecTan, self).__init__()
        self.lambda_ = lambda_
        self.encoder = nn.Linear(num_items, hidden_dim, bias=True)
        self.decoder = nn.Linear(hidden_dim, num_items, bias=True)
        self.tanh = nn.Tanh()
        self.dropout = nn.Dropout(p)

    def forward(self, x):
        encoded = self.dropout(self.tanh(self.encoder(x)))
        decoded = self.decoder(encoded)
        return decoded

    def regularization_loss(self):
        reg_loss = 0
        for param in self.parameters():
            reg_loss += param.norm(2)
        return self.lambda_ * reg_loss

# %%
class AutoRecRel(nn.Module):
    def __init__(self, num_items, hidden_dim, lambda_, p=0.2):
        super(AutoRecRel, self).__init__()
        self.lambda_ = lambda_
        self.encoder = nn.Linear(num_items, hidden_dim, bias=True)
        self.decoder = nn.Linear(hidden_dim, num_items, bias=True)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(p)

    def forward(self, x):
        encoded = self.dropout(self.relu(self.encoder(x)))
        decoded = self.decoder(encoded)
        return decoded

    def regularization_loss(self):
        reg_loss = 0
        for param in self.parameters():
            reg_loss += param.norm(2)
        return self.lambda_ * reg_loss

# %%
def impute_missing_values(batch):
    """
    Impute missing values in the batch with row-wise means (mean of observed ratings).
    """
    batch_imputed = batch.clone()  # Clone to avoid modifying the original tensor
    for i in range(batch_imputed.size(0)):  # Iterate over rows (movies)
        row = batch_imputed[i]
        observed = row[row > 0]  # Mask to find observed ratings
        if observed.numel() > 0:
            mean_rating = observed.mean()
            row[row == 0] = mean_rating  # Replace missing values (0s) with mean
    return batch_imputed

# %%
# def train_epoch(model, train_data, optimizer, criterion, batch_size):
#     model.train()
#     num_batches = train_data.size(0) // batch_size
#     total_loss = 0

#     for i in range(num_batches):
#         batch = train_data[i * batch_size:(i + 1) * batch_size].to(device)

#         optimizer.zero_grad()
#         predictions = model(batch)
#         mask = batch > 0 
#         loss = criterion(predictions[mask], batch[mask]) + model.regularization_loss()
#         loss.backward()
#         optimizer.step()

#         total_loss += loss.item()

#     return total_loss / num_batches

# %%
def train_epoch(model, train_data, optimizer, criterion, batch_size):
    model.train()
    num_batches = train_data.size(0) // batch_size
    total_loss = 0

    for i in range(num_batches):
        batch = train_data[i * batch_size:(i + 1) * batch_size].to(device)

        # Impute missing values
        batch_imputed = impute_missing_values(batch)

        optimizer.zero_grad()
        predictions = model(batch_imputed)  # Use imputed data as input
        mask = batch > 0  # Use original batch to calculate loss
        loss = criterion(predictions[mask], batch[mask]) + model.regularization_loss()
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    return total_loss / num_batches

# %%
def evaluate_model(model, test_data, criterion, batch_size):
    model.eval()
    num_batches = test_data.size(0) // batch_size
    total_loss = 0

    with torch.no_grad():
        for i in range(num_batches):
            batch = test_data[i * batch_size:(i + 1) * batch_size].to(device)

            predictions = model(batch)
            mask = batch > 0 
            loss = criterion(predictions[mask], batch[mask])
            total_loss += loss.item()

    return total_loss / num_batches

# %%
# Hyperparameters
hidden_dim = 50
lambda_ = 0.001
learning_rate = 0.001
batch_size = 32
epochs = 50
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
# Initialize model, optimizer, and loss function
model = AutoRecSig(num_movies, hidden_dim, lambda_).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=5e-4)
criterion = nn.MSELoss()

# %%
train_tensor = train_matrix.to(device)
test_tensor = test_matrix.to(device)
val_tensor = val_matrix.to(device)

# %%
train_losses, val_losses = [], []

# %%
for epoch in range(epochs):
    train_loss = train_epoch(model, train_tensor, optimizer, criterion, batch_size)
    val_loss = evaluate_model(model, val_tensor, criterion, batch_size)

    train_losses.append(train_loss)
    val_losses.append(val_loss)
    
    print(f"Epoch {epoch + 1}/{epochs}, Train Loss: {train_loss:.4f}, Validation Loss: {val_loss:.4f}")
# Out:
# Epoch 1/50, Train Loss: 0.5853, Validation Loss: 0.4602
# Epoch 2/50, Train Loss: 0.5338, Validation Loss: 0.4294
# Epoch 3/50, Train Loss: 0.4976, Validation Loss: 0.4072
# Epoch 4/50, Train Loss: 0.4463, Validation Loss: 0.3745
# Epoch 5/50, Train Loss: 0.3934, Validation Loss: 0.3449
# Epoch 6/50, Train Loss: 0.3462, Validation Loss: 0.3208
# Epoch 7/50, Train Loss: 0.3084, Validation Loss: 0.3027
# %%
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Testing Loss')
plt.show()

# %%
def calculate_rmse(model, data, batch_size):
    model.eval()
    num_batches = data.size(0) // batch_size
    mse = 0
    total_ratings = 0

    with torch.no_grad():
        for i in range(num_batches):
            batch = data[i * batch_size:(i + 1) * batch_size].to(device)
            predictions = model(batch)
            mask = batch > 0
            
            mse += ((predictions[mask] - batch[mask]) ** 2).sum().item()
            total_ratings += mask.sum().item()

    return np.sqrt(mse / total_ratings)

# %%
rmse = calculate_rmse(model, test_tensor, batch_size)
print(f"Test RMSE: {rmse:.4f}")
# Out:
# Test RMSE: 0.3450

# %%
import numpy as np
import torch
from torch import nn

# Calculate RMSE
def calculate_rmse(model, data, batch_size):
    model.eval()
    num_batches = data.size(0) // batch_size
    mse = 0
    total_ratings = 0

    with torch.no_grad():
        for i in range(num_batches):
            batch = data[i * batch_size:(i + 1) * batch_size].to(device)
            predictions = model(batch)
            mask = batch > 0
            
            mse += ((predictions[mask] - batch[mask]) ** 2).sum().item()
            total_ratings += mask.sum().item()

    return np.sqrt(mse / total_ratings)

# Calculate MAE
def calculate_mae(model, data, batch_size):
    model.eval()
    num_batches = data.size(0) // batch_size
    mae = 0
    total_ratings = 0

    with torch.no_grad():
        for i in range(num_batches):
            batch = data[i * batch_size:(i + 1) * batch_size].to(device)
            predictions = model(batch)
            mask = batch > 0
            
            mae += (predictions[mask] - batch[mask]).abs().sum().item()
            total_ratings += mask.sum().item()

    return mae / total_ratings

# Calculate MSE
def calculate_mse(model, data, batch_size):
    model.eval()
    num_batches = data.size(0) // batch_size
    mse = 0
    total_ratings = 0

    with torch.no_grad():
        for i in range(num_batches):
            batch = data[i * batch_size:(i + 1) * batch_size].to(device)
            predictions = model(batch)
            mask = batch > 0
            
            mse += ((predictions[mask] - batch[mask]) ** 2).sum().item()
            total_ratings += mask.sum().item()

    return mse / total_ratings

# Calculate R-Squared
def calculate_r2(model, data, batch_size):
    model.eval()
    num_batches = data.size(0) // batch_size
    ss_total = 0
    ss_residual = 0

    with torch.no_grad():
        for i in range(num_batches):
            batch = data[i * batch_size:(i + 1) * batch_size].to(device)
            predictions = model(batch)
            mask = batch > 0

            mean_rating = batch[mask].mean().item()
            ss_total += ((batch[mask] - mean_rating) ** 2).sum().item()
            ss_residual += ((predictions[mask] - batch[mask]) ** 2).sum().item()

    return 1 - (ss_residual / ss_total)

# Calculate Explained Variance
def calculate_explained_variance(model, data, batch_size):
    model.eval()
    variance_explained = 0
    variance_total = 0

    with torch.no_grad():
        for i in range(data.size(0) // batch_size):
            batch = data[i * batch_size:(i + 1) * batch_size].to(device)
            predictions = model(batch)
            mask = batch > 0

            batch_var = ((batch[mask] - batch[mask].mean()) ** 2).sum().item()
            residual_var = ((batch[mask] - predictions[mask]) ** 2).sum().item()

            variance_total += batch_var
            variance_explained += (batch_var - residual_var)

    return variance_explained / variance_total

# %%
batch_size = 32

rmse = calculate_rmse(model, test_tensor, batch_size)
mae = calculate_mae(model, test_tensor, batch_size)
mse = calculate_mse(model, test_tensor, batch_size)
r2 = calculate_r2(model, test_tensor, batch_size)
explained_variance = calculate_explained_variance(model, test_tensor, batch_size)

print(f"Test RMSE: {rmse:.4f}")
print(f"Test MAE: {mae:.4f}")
print(f"Test MSE: {mse:.4f}")
print(f"Test R2: {r2:.4f}")
print(f"Test Explained Variance: {explained_variance:.4f}")
# Out:
# Test RMSE: 0.3450
# Test MAE: 0.2931
# Test MSE: 0.1190
# Test R2: -1.3679
# Test Explained Variance: -1.3679

# %%
import math
import torch

def evaluate_metrics(model, test_matrix, test_user_mapping, k=10, device="cpu"):
    hr, ndcg, precision, recall, mrr = 0, 0, 0, 0, 0
    total_users = 0

    model.eval()
    with torch.no_grad():
        for user_id, user_idx in test_user_mapping.items():
            # Get user interactions for the current user
            user_ratings = test_matrix[user_idx].to(device)
            observed_ratings = user_ratings[user_ratings > 0]

            # Skip users with no observed ratings
            if observed_ratings.numel() == 0:
                continue

            # Calculate personalized threshold (e.g., mean)
            user_threshold = observed_ratings.mean()  # Replace with median or percentile if needed
            ground_truth = torch.nonzero(user_ratings >= user_threshold, as_tuple=True)[0].tolist()

            # Skip users with no relevant items
            if not ground_truth:
                continue

            # Predict scores for all items
            predictions = model(user_ratings.unsqueeze(0)).squeeze(0).cpu()

            # Top-K predictions
            top_k = min(k, len(predictions))
            predicted_top_k = torch.argsort(predictions, descending=True)[:top_k].tolist()

            # Calculate hits
            hits = len(set(ground_truth) & set(predicted_top_k))

            # Update metrics
            hr += 1 if hits > 0 else 0
            precision += hits / top_k
            recall += hits / len(ground_truth)

            # Compute NDCG
            dcg = sum(
                1 / math.log2(i + 2) if predicted_top_k[i] in ground_truth else 0
                for i in range(top_k)
            )
            idcg = sum(1 / math.log2(i + 2) for i in range(min(len(ground_truth), top_k)))
            ndcg += dcg / idcg if idcg > 0 else 0

            # Compute MRR
            for rank, item in enumerate(predicted_top_k):
                if item in ground_truth:
                    mrr += 1 / (rank + 1)
                    break

            total_users += 1

    # Handle cases where no users are evaluated
    if total_users == 0:
        return {"HR": 0, "NDCG": 0, "Precision": 0, "Recall": 0, "MRR": 0}

    # Compute averages and return results as percentages
    return {
        "HR": (hr / total_users),
        "NDCG": (ndcg / total_users),
        "Precision": (precision / total_users),
        "Recall": (recall / total_users),
        "MRR": (mrr / total_users),
    }

# %%
k = 10
metrics = evaluate_metrics(model, test_matrix, test_user_mapping, k=k)

print(f"Hit Ratio-{k}: {metrics['HR']:.2f}")
print(f"NDCG-{k}: {metrics['NDCG']:.2f}")
print(f"Precision-{k}: {metrics['Precision']:.2f}")
print(f"Recall-{k}: {metrics['Recall']:.2f}")
print(f"MRR: {metrics['MRR']:.2f}")
# Out:
# Hit Ratio-10: 0.78
# NDCG-10: 0.24
# Precision-10: 0.24
# Recall-10: 0.06
# MRR: 0.40

# %% [markdown]
# The model demonstrates strong candidate selection with a Hit Ratio-10 of 80.33%, indicating its effectiveness in recommending at least one relevant item for most users. However, a NDCG-10 of 20.41% and MRR of 25.85% suggest room for improvement in ranking relevant items higher within the top-10. While Precision-10 of 23.69% reflects moderate relevance in predictions, the low Recall-10 of 3.36% highlights limitations in covering all relevant items. Overall, the model performs well at identifying some relevant items but needs refinement in ranking and recall for better recommendation quality.
#
# **Hit Ratio (HR):** Measures how often the true item appears in the Top-K list of recommendations. A higher hit ratio indicates a better model.
#
# **Normalized Discounted Cumulative Gain (NDCG):** Takes into account the position of the relevant item in the ranking. Higher scores are given if relevant items appear higher in the list.
#
# **Precision@K:** Measures the proportion of the Top-K recommendations that are relevant.
#
# **Recall@K:** Measures the proportion of all relevant items that are included in the Top-K list.
#
# **Mean Reciprocal Rank (MRR):** Measures the rank of the first relevant item, giving higher scores if it appears earlier in the list.

# %%
def print_top_k_movies_with_titles(ratings, user_mapping, movie_mapping, predictions, k, movies_path):
    """
    Print the top-k actual and predicted movies for each user with movie titles.

    Args:
        ratings: Original ratings dataframe.
        user_mapping: Dictionary mapping user IDs to internal IDs.
        movie_mapping: Dictionary mapping movie IDs to internal IDs.
        predictions: Predicted ratings matrix.
        k: Number of top movies to display.
        movies_path: Path to the 'movies.csv' file for fetching movie titles.
    """
    # Load movie titles
    movies = pd.read_csv(movies_path)
    reverse_movie_mapping = {v: k for k, v in movie_mapping.items()}
    movie_id_to_title = {row['movieId']: row['title'] for _, row in movies.iterrows()}

    # Iterate through all users in the test set
    for user_id in range(predictions.shape[0]):
        # Get the actual top-k movies for the user
        actual_movies = ratings[ratings['userId'] == user_id].nlargest(k, 'rating')['movieId'].values
        # Map actual movie IDs to titles
        actual_titles = [movie_id_to_title.get(reverse_movie_mapping.get(movie), "Unknown") for movie in actual_movies]

        # Get the predicted top-k movies for the user
        predicted_scores = predictions[user_id].cpu().numpy()  # Convert tensor to numpy array
        top_k_indices = np.argsort(predicted_scores)[-k:][::-1]
        predicted_movies = [reverse_movie_mapping[idx] for idx in top_k_indices]
        # Map predicted movie IDs to titles
        predicted_titles = [movie_id_to_title.get(movie, "Unknown") for movie in predicted_movies]

        # Print results
        print(f"User {user_id + 1}:")
        print(f"  Actual Top Movies: {actual_titles}")
        print(f"  Predicted Top Movies: {predicted_titles}")
        print("----------------------------------------")

# %%
# Generate predictions
model.eval()  # Set the model to evaluation mode
with torch.no_grad():
    predictions = model(test_matrix)

# Call the function to print top-K movies
print_top_k_movies_with_titles(ratings, user_mapping, movie_mapping, predictions, k=10,  movies_path='ml-latest-small/movies.csv')
# Out:
# User 1:
#   Actual Top Movies: ['Seven (a.k.a. Se7en) (1995)', 'Usual Suspects, The (1995)', 'Bottle Rocket (1996)', 'Rob Roy (1995)', 'Canadian Bacon (1995)', 'Desperado (1995)', 'Billy Madison (1995)', 'Dumb & Dumber (Dumb and Dumber) (1994)', 'Star Wars: Episode IV - A New Hope (1977)', 'Tommy Boy (1995)']
#   Predicted Top Movies: ['Star Wars: Episode IV - A New Hope (1977)', 'Matrix, The (1999)', 'Fight Club (1999)', 'Forrest Gump (1994)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Saving Private Ryan (1998)', 'Seven (a.k.a. Se7en) (1995)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)', 'Monty Python and the Holy Grail (1975)']
# ----------------------------------------
# User 2:
#   Actual Top Movies: ['Step Brothers (2008)', 'Inside Job (2010)', 'Warrior (2011)', 'Wolf of Wall Street, The (2013)', 'Mad Max: Fury Road (2015)', 'The Jinx: The Life and Deaths of Robert Durst (2015)', 'Good Will Hunting (1997)', 'Dark Knight, The (2008)', 'Inglourious Basterds (2009)', 'Town, The (2010)']
#   Predicted Top Movies: ['Star Wars: Episode IV - A New Hope (1977)', 'Matrix, The (1999)', 'Fight Club (1999)', 'Saving Private Ryan (1998)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Forrest Gump (1994)', "Schindler's List (1993)", 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Godf
'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Godfather: Part II, The (1974)', 'Seven (a.k.a. Se7en) (1995)']
# ----------------------------------------

# %% [markdown]
# # Choosing hyperparameters

# %%
# import itertools
# from sklearn.model_selection import KFold
# import numpy as np
# import torch
# from torch import nn

# # Define hyperparameter grid
# param_grid = {
#     'hidden_dim': [50, 100, 200],
#     'lambda_': [0.0001, 0.001, 0.01],
#     'learning_rate': [0.001, 0.0001, 0.00001],
#     'batch_size': [32, 64, 128],
# }

# param_combinations = list(itertools.product(*param_grid.values()))

# # Define K-Fold Cross-Validation
# k_folds = 5
# kf = KFold(n_splits=k_folds, shuffle=True, random_state=42)

# # Function to train and evaluate using K-Fold Cross-Validation
# def train_and_evaluate_kfold(params, full_matrix, k_folds):
#     # Unpack parameters
#     hidden_dim, lambda_, learning_rate, batch_size= params

#     # Initialize storage for RMSE scores
#     fold_rmse_scores = []

#     # Perform K-Fold Cross-Validation
#     for train_idx, val_idx in kf.split(full_matrix):
#         # Create train and validation matrices
#         train_matrix = torch.zeros_like(full_matrix)
#         val_matrix = torch.zeros_like(full_matrix)
        
#         # Populate train and validation matrices
#         train_matrix[train_idx] = full_matrix[train_idx]
#         val_matrix[val_idx] = full_matrix[val_idx]
        
#         # Initialize model, optimizer, and loss function
#         model = AutoRecRel(num_movies, hidden_dim, lambda_).to(device)
#         optimizer = torch.optim.Adam(
#             model.parameters(),
#             lr=learning_rate,
#         )
#         criterion = nn.MSELoss()

#         # Train the model
#         train_tensor = train_matrix.to(device)
#         val_tensor = val_matrix.to(device)
#         for epoch in range(100):  # Fewer epochs for faster cross-validation
#             train_epoch(model, train_tensor, optimizer, criterion, batch_size)

#             # Evaluate the model on the validation set after each epoch
#             val_loss = evaluate_model(model, val_tensor, criterion, batch_size)

#         # Final evaluation for this fold
#         rmse = calculate_rmse(model, val_tensor, batch_size)
#         fold_rmse_scores.append(rmse)

#     # Return the average RMSE across all folds
#     return np.mean(fold_rmse_scores)

# # Track best hyperparameters and performance
# best_params = None
# best_rmse = float('inf')

# # Perform hyperparameter search
# for i, params in enumerate(param_combinations):
#     print(f"Testing combination {i+1}/{len(param_combinations)}: {params}")
#     rmse = train_and_evaluate_kfold(params, user_item_matrix, k_folds)

#     print(f"Average RMSE across {k_folds} folds: {rmse:.4f}")

#     # Update best parameters if current RMSE is better
#     if rmse < best_rmse:
#         best_rmse = rmse
#         best_params = params

# # Print the best hyperparameters
# best_param_dict = dict(zip(param_grid.keys(), best_params))
# print(f"\nRelU Best Hyperparameters: {best_param_dict}")
# print(f"Best RMSE: {best_rmse:.4f}")
# Out:
# Testing combination 1/81: (50, 0.0001, 0.001, 32)
# Average RMSE across 5 folds: 0.2833
# Testing combination 2/81: (50, 0.0001, 0.001, 64)
# Average RMSE across 5 folds: 0.3032
# Testing combination 3/81: (50, 0.0001, 0.001, 128)
# Average RMSE across 5 folds: 0.3183
# Testing combination 4/81: (50, 0.0001, 0.0001, 32)
# Average RMSE across 5 folds: 0.4031
# Testing combination 5/81: (50, 0.0001, 0.0001, 64)
# Average RMSE across 5 folds: 0.4601
# Testing combination 6/81: (50, 0.0001, 0.0001, 128)
# Average RMSE across 5 folds: 0.4771
# Testing combination 7/81: (50, 0.0001, 1e-05, 32)
# Average RMSE across 5 folds: 0.5261
# Testing combination 8/81: (50, 0.0001, 1e-05, 64)
# Average RMSE across 5 folds: 0.6227
# Testing combination 9/81: (50, 0.0001, 1e-05, 128)
# Average RMSE across 5 folds: 0.6882
# Testing combination 10/81: (50, 0.001, 0.001, 32)
# Average RMSE across 5 folds: 0.2973
# Testing combination 11/81: (50, 0.001, 0.001, 64)
# Average RMSE across 5 folds: 0.3249
# Testing combination 12/81: (50, 0.001, 0.001, 128)
# Average RMSE across 5 folds: 0.3190
# Testing combination 13/81: (50, 0.001, 0.0001, 32)
# Average RMSE across 5 folds: 0.3829
# Testing combination 14/81: (50, 0.001, 0.0001, 64)
# Average RMSE across 5 folds: 0.4391
# Testing combination 15/81: (50, 0.001, 0.0001, 128)
# Average RMSE across 5 folds: 0.4685
# Testing combination 16/81: (50, 0.001, 1e-05, 32)
# Average RMSE across 5 folds: 0.5259
# Testing combination 17/81: (50, 0.001, 1e-05, 64)
# Average RMSE across 5 folds: 0.6208
# Testing combination 18/81: (50, 0.001, 1e-05, 128)
# Average RMSE across 5 folds: 0.6885
# Testing combination 19/81: (50, 0.01, 0.001, 32)
# Average RMSE across 5 folds: 0.3521
# Testing combination 20/81: (50, 0.01, 0.001, 64)
# Average RMSE across 5 folds: 0.3656
# Testing combination 21/81: (50, 0.01, 0.001, 128)
# Average RMSE across 5 folds: 0.3742
# Testing combination 22/81: (50, 0.01, 0.0001, 32)
# Average RMSE across 5 folds: 0.3546
# Testing combination 23/81: (50, 0.01, 0.0001, 64)
# Average RMSE across 5 folds: 0.3937
# Testing combination 24/81: (50, 0.01, 0.0001, 128)
# Average RMSE across 5 folds: 0.4185
# Testing combination 25/81: (50, 0.01, 1e-05, 32)
# Average RMSE across 5 folds: 0.5295
# Testing combination 26/81: (50, 0.01, 1e-05, 64)
# Average RMSE across 5 folds: 0.6337
# Testing combination 27/81: (50, 0.01, 1e-05, 128)
# Average RMSE across 5 folds: 0.6948
# Testing combination 28/81: (100, 0.0001, 0.001, 32)
# Average RMSE across 5 folds: 0.2932
# Testing combination 29/81: (100, 0.0001, 0.001, 64)
# Average RMSE across 5 folds: 0.3150
# Testing combination 30/81: (100, 0.0001, 0.001, 128)
# Average RMSE across 5 folds: 0.3252
# Testing combination 31/81: (100, 0.0001, 0.0001, 32)
# Average RMSE across 5 folds: 0.3784
# Testing combination 32/81: (100, 0.0001, 0.0001, 64)
# Average RMSE across 5 folds: 0.4670
# Testing combination 33/81: (100, 0.0001, 0.0001, 128)
# Average RMSE across 5 folds: 0.4935
# Testing combination 34/81: (100, 0.0001, 1e-05, 32)
# Average RMSE across 5 folds: 0.4559
# Testing combination 35/81: (100, 0.0001, 1e-05, 64)
# Average RMSE across 5 folds: 0.5361
# Testing combination 36/81: (100, 0.0001, 1e-05, 128)
# Average RMSE across 5 folds: 0.6310
# Testing combination 37/81: (100, 0.001, 0.001, 32)
# Average RMSE across 5 folds: 0.3065
# Testing combination 38/81: (100, 0.001, 0.001, 64)
# Average RMSE across 5 folds: 0.3084
# Testing combination 39/81: (100, 0.001, 0.001, 128)
# Average RMSE across 5 folds: 0.3150
# Testing combination 40/81: (100, 0.001, 0.0001, 32)
# Average RMSE across 5 folds: 0.3643
# Testing combination 41/81: (100, 0.001, 0.0001, 64)
# Average RMSE across 5 folds: 0.4401
# Testing combination 42/81: (100, 0.001, 0.0001, 128)
# Average RMSE across 5 folds: 0.4757
# Testing combination 43/81: (100, 0.001, 1e-05, 32)
# Average RMSE across 5 folds: 0.4544
# Testing combination 44/81: (100, 0.001, 1e-05, 64)
# Average RMSE across 5 folds: 0.5367
# Testing combination 45/81: (100, 0.001, 1e-05, 128)
# Average RMSE across 5 folds: 0.6332
# Testing combination 46/81: (100, 0.01, 0.001, 32)
# Average RMSE across 5 folds: 0.3564
# Testing combination 47/81: (100, 0.01, 0.001, 64)
# Average RMSE across 5 folds: 0.3763
# Testing combination 48/81: (100, 0.01, 0.001, 128)
# Average RMSE across 5 folds: 0.3743
# Testing combination 49/81: (100, 0.01, 0.0001, 32)
# Average RMSE across 5 folds: 0.3576
# Testing combination 50/81: (100, 0.01, 0.0001, 64)
# Average RMSE across 5 folds: 0.3804
# Testing combination 51/81: (100, 0.01, 0.0001, 128)
# Average RMSE across 5 folds: 0.4123
# Testing combination 52/81: (100, 0.01, 1e-05, 32)
# Average RMSE across 5 folds: 0.4515
# Testing combination 53/81: (100, 0.01, 1e-05, 64)
# Average RMSE across 5 folds: 0.5373
# Testing combination 54/81: (100, 0.01, 1e-05, 128)
# Average RMSE across 5 folds: 0.6438
# Testing combination 55/81: (200, 0.0001, 0.001, 32)
# Average RMSE across 5 folds: 0.3171
# Testing combination 56/81: (200, 0.0001, 0.001, 64)
# Average RMSE across 5 folds: 0.3224
# Testing combination 57/81: (200, 0.0001, 0.001, 128)
# Average RMSE across 5 folds: 0.3399
# Testing combination 58/81: (200, 0.0001, 0.0001, 32)
# Average RMSE across 5 folds: 0.3252
# Testing combination 59/81: (200, 0.0001, 0.0001, 64)
# Average RMSE across 5 folds: 0.4158
# Testing combination 60/81: (200, 0.0001, 0.0001, 128)
# Average RMSE across 5 folds: 0.4912
# Testing combination 61/81: (200, 0.0001, 1e-05, 32)
# Average RMSE across 5 folds: 0.4340
# Testing combination 62/81: (200, 0.0001, 1e-05, 64)
# Average RMSE across 5 folds: 0.4820
# Testing combination 63/81: (200, 0.0001, 1e-05, 128)
# Average RMSE across 5 folds: 0.5580
# Testing combination 64/81: (200, 0.001, 0.001, 32)
# Average RMSE across 5 folds: 0.3074
# Testing combination 65/81: (200, 0.001, 0.001, 64)
# Average RMSE across 5 folds: 0.3126
# Testing combination 66/81: (200, 0.001, 0.001, 128)
# Average RMSE across 5 folds: 0.3177
# Testing combination 67/81: (200, 0.001, 0.0001, 32)
# Average RMSE across 5 folds: 0.3399
# Testing combination 68/81: (200, 0.001, 0.0001, 64)
# Average RMSE across 5 folds: 0.4136
# Testing combination 69/81: (200, 0.001, 0.0001, 128)
# Average RMSE across 5 folds: 0.4722
# Testing combination 70/81: (200, 0.001, 1e-05, 32)
# Average RMSE across 5 folds: 0.4307
# Testing combination 71/81: (200, 0.001, 1e-05, 64)
# Average RMSE across 5 folds: 0.4825
# Testing combination 72/81: (200, 0.001, 1e-05, 128)
# Average RMSE across 5 folds: 0.5552
# Testing combination 73/81: (200, 0.01, 0.001, 32)
# Average RMSE across 5 folds: 0.3688
# Testing combination 74/81: (200, 0.01, 0.001, 64)
# Average RMSE across 5 folds: 0.3794
# Testing combination 75/81: (200, 0.01, 0.001, 128)
# Average RMSE across 5 folds: 0.3713
# Testing combination 76/81: (200, 0.01, 0.0001, 32)
# Average RMSE across 5 folds: 0.3723
# Testing combination 77/81: (200, 0.01, 0.0001, 64)
# Average RMSE across 5 folds: 0.3825
# Testing combination 78/81: (200, 0.01, 0.0001, 128)
# Average RMSE across 5 folds: 0.4072
# Testing combination 79/81: (200, 0.01, 1e-05, 32)
# Average RMSE across 5 folds: 0.4247
# Testing combination 80/81: (200, 0.01, 1e-05, 64)
# Average RMSE across 5 folds: 0.4796
# Testing combination 81/81: (200, 0.01, 1e-05, 128)
# Average RMSE across 5 folds: 0.5625
#
# RelU Best Hyperparameters: {'hidden_dim': 50, 'lambda_': 0.0001, 'learning_rate': 0.001, 'batch_size': 32}
# Best RMSE: 0.2833

# %%
# import itertools
# from sklearn.model_selection import KFold
# import numpy as np
# import torch
# from torch import nn

# # Define hyperparameter grid
# param_grid = {
#     'hidden_dim': [50, 100, 200],
#     'lambda_': [0.0001, 0.001, 0.01],
#     'learning_rate': [0.001, 0.0001, 0.00001],
#     'batch_size': [32, 64, 128],
# }

# param_combinations = list(itertools.product(*param_grid.values()))

# # Define K-Fold Cross-Validation
# k_folds = 5
# kf = KFold(n_splits=k_folds, shuffle=True, random_state=42)

# # Function to train and evaluate using K-Fold Cross-Validation
# def train_and_evaluate_kfold(params, full_matrix, k_folds):
#     # Unpack parameters
#     hidden_dim, lambda_, learning_rate, batch_size= params

#     # Initialize storage for RMSE scores
#     fold_rmse_scores = []

#     # Perform K-Fold Cross-Validation
#     for train_idx, val_idx in kf.split(full_matrix):
#         # Create train and validation matrices
#         train_matrix = torch.zeros_like(full_matrix)
#         val_matrix = torch.zeros_like(full_matrix)
        
#         # Populate train and validation matrices
#         train_matrix[train_idx] = full_matrix[train_idx]
#         val_matrix[val_idx] = full_matrix[val_idx]
        
#         # Initialize model, optimizer, and loss function
#         model = AutoRecTan(num_movies, hidden_dim, lambda_).to(device)
#         optimizer = torch.optim.Adam(
#             model.parameters(),
#             lr=learning_rate,
#         )
#         criterion = nn.MSELoss()

#         # Train the model
#         train_tensor = train_matrix.to(device)
#         val_tensor = val_matrix.to(device)
#         for epoch in range(100):  # Fewer epochs for faster cross-validation
#             train_epoch(model, train_tensor, optimizer, criterion, batch_size)

#             # Evaluate the model on the validation set after each epoch
#             val_loss = evaluate_model(model, val_tensor, criterion, batch_size)

#         # Final evaluation for this fold
#         rmse = calculate_rmse(model, val_tensor, batch_size)
#         fold_rmse_scores.append(rmse)

#     # Return the average RMSE across all folds
#     return np.mean(fold_rmse_scores)

# # Track best hyperparameters and performance
# best_params = None
# best_rmse = float('inf')

# # Perform hyperparameter search
# for i, params in enumerate(param_combinations):
#     print(f"Testing combination {i+1}/{len(param_combinations)}: {params}")
#     rmse = train_and_evaluate_kfold(params, user_item_matrix, k_folds)

#     print(f"Average RMSE across {k_folds} folds: {rmse:.4f}")

#     # Update best parameters if current RMSE is better
#     if rmse < best_rmse:
#         best_rmse = rmse
#         best_params = params

# # Print the best hyperparameters
# best_param_dict = dict(zip(param_grid.keys(), best_params))
# print(f"\nTanh Best Hyperparameters: {best_param_dict}")
# print(f"Best RMSE: {best_rmse:.4f}")
# Out:
# Testing combination 1/81: (50, 0.0001, 0.001, 32)
# Average RMSE across 5 folds: 0.2834
# Testing combination 2/81: (50, 0.0001, 0.001, 64)
# Average RMSE across 5 folds: 0.2988
# Testing combination 3/81: (50, 0.0001, 0.001, 128)
# Average RMSE across 5 folds: 0.3312
# Testing combination 4/81: (50, 0.0001, 0.0001, 32)
# Average RMSE across 5 folds: 0.3410
# Testing combination 5/81: (50, 0.0001, 0.0001, 64)
# Average RMSE across 5 folds: 0.3534
# Testing combination 6/81: (50, 0.0001, 0.0001, 128)
# Average RMSE across 5 folds: 0.3564
# Testing combination 7/81: (50, 0.0001, 1e-05, 32)
# Average RMSE across 5 folds: 0.4954
# Testing combination 8/81: (50, 0.0001, 1e-05, 64)
# Average RMSE across 5 folds: 0.5986
# Testing combination 9/81: (50, 0.0001, 1e-05, 128)
# Average RMSE across 5 folds: 0.6758
# Testing combination 10/81: (50, 0.001, 0.001, 32)
# Average RMSE across 5 folds: 0.2806
# Testing combination 11/81: (50, 0.001, 0.001, 64)
# Average RMSE across 5 folds: 0.2961
# Testing combination 12/81: (50, 0.001, 0.001, 128)
# Average RMSE across 5 folds: 0.3274
# Testing combination 13/81: (50, 0.001, 0.0001, 32)
# Average RMSE across 5 folds: 0.3318
# Testing combination 14/81: (50, 0.001, 0.0001, 64)
# Average RMSE across 5 folds: 0.3544
# Testing combination 15/81: (50, 0.001, 0.0001, 128)
# Average RMSE across 5 folds: 0.3569
# Testing combination 16/81: (50, 0.001, 1e-05, 32)
# Average RMSE across 5 folds: 0.4964
# Testing combination 17/81: (50, 0.001, 1e-05, 64)
# Average RMSE across 5 folds: 0.5964
# Testing combination 18/81: (50, 0.001, 1e-05, 128)
# Average RMSE across 5 folds: 0.6747
# Testing combination 19/81: (50, 0.01, 0.001, 32)
# Average RMSE across 5 folds: 0.2794
# Testing combination 20/81: (50, 0.01, 0.001, 64)
# Average RMSE across 5 folds: 0.2959
# Testing combination 21/81: (50, 0.01, 0.001, 128)
# Average RMSE across 5 folds: 0.3272
# Testing combination 22/81: (50, 0.01, 0.0001, 32)
# Average RMSE across 5 folds: 0.3365
# Testing combination 23/81: (50, 0.01, 0.0001, 64)
# Average RMSE across 5 folds: 0.3549
# Testing combination 24/81: (50, 0.01, 0.0001, 128)
# Average RMSE across 5 folds: 0.3583
# Testing combination 25/81: (50, 0.01, 1e-05, 32)
# Average RMSE across 5 folds: 0.4943
# Testing combination 26/81: (50, 0.01, 1e-05, 64)
# Average RMSE across 5 folds: 0.5986
# Testing combination 27/81: (50, 0.01, 1e-05, 128)
# Average RMSE across 5 folds: 0.6735
# Testing combination 28/81: (100, 0.0001, 0.001, 32)
# Average RMSE across 5 folds: 0.2778
# Testing combination 29/81: (100, 0.0001, 0.001, 64)
# Average RMSE across 5 folds: 0.2886
# Testing combination 30/81: (100, 0.0001, 0.001, 128)
# Average RMSE across 5 folds: 0.3258
# Testing combination 31/81: (100, 0.0001, 0.0001, 32)
# Average RMSE across 5 folds: 0.3386
# Testing combination 32/81: (100, 0.0001, 0.0001, 64)
# Average RMSE across 5 folds: 0.3735
# Testing combination 33/81: (100, 0.0001, 0.0001, 128)
# Average RMSE across 5 folds: 0.3730
# Testing combination 34/81: (100, 0.0001, 1e-05, 32)
# Average RMSE across 5 folds: 0.4061
# Testing combination 35/81: (100, 0.0001, 1e-05, 64)
# Average RMSE across 5 folds: 0.4905
# Testing combination 36/81: (100, 0.0001, 1e-05, 128)
# Average RMSE across 5 folds: 0.6072
# Testing combination 37/81: (100, 0.001, 0.001, 32)
# Average RMSE across 5 folds: 0.2819
# Testing combination 38/81: (100, 0.001, 0.001, 64)
# Average RMSE across 5 folds: 0.2928
# Testing combination 39/81: (100, 0.001, 0.001, 128)
# Average RMSE across 5 folds: 0.3178
# Testing combination 40/81: (100, 0.001, 0.0001, 32)
# Average RMSE across 5 folds: 0.3409
# Testing combination 41/81: (100, 0.001, 0.0001, 64)
# Average RMSE across 5 folds: 0.3716
# Testing combination 42/81: (100, 0.001, 0.0001, 128)
# Average RMSE across 5 folds: 0.3702
# Testing combination 43/81: (100, 0.001, 1e-05, 32)
# Average RMSE across 5 folds: 0.4075
# Testing combination 44/81: (100, 0.001, 1e-05, 64)
# Average RMSE across 5 folds: 0.4884
# Testing combination 45/81: (100, 0.001, 1e-05, 128)
# Average RMSE across 5 folds: 0.6069
# Testing combination 46/81: (100, 0.01, 0.001, 32)
# Average RMSE across 5 folds: 0.2782
# Testing combination 47/81: (100, 0.01, 0.001, 64)
# Average RMSE across 5 folds: 0.2927
# Testing combination 48/81: (100, 0.01, 0.001, 128)
# Average RMSE across 5 folds: 0.3258
# Testing combination 49/81: (100, 0.01, 0.0001, 32)
# Average RMSE across 5 folds: 0.3455
# Testing combination 50/81: (100, 0.01, 0.0001, 64)
# Average RMSE across 5 folds: 0.3693
# Testing combination 51/81: (100, 0.01, 0.0001, 128)
# Average RMSE across 5 folds: 0.3735
# Testing combination 52/81: (100, 0.01, 1e-05, 32)
# Average RMSE across 5 folds: 0.4068
# Testing combination 53/81: (100, 0.01, 1e-05, 64)
# Average RMSE across 5 folds: 0.4894
# Testing combination 54/81: (100, 0.01, 1e-05, 128)
# Average RMSE across 5 folds: 0.6058
# Testing combination 55/81: (200, 0.0001, 0.001, 32)
# Average RMSE across 5 folds: 0.2822
# Testing combination 56/81: (200, 0.0001, 0.001, 64)
# Average RMSE across 5 folds: 0.2892
# Testing combination 57/81: (200, 0.0001, 0.001, 128)
# Average RMSE across 5 folds: 0.3038
# Testing combination 58/81: (200, 0.0001, 0.0001, 32)
# Average RMSE across 5 folds: 0.3579
# Testing combination 59/81: (200, 0.0001, 0.0001, 64)
# Average RMSE across 5 folds: 0.3785
# Testing combination 60/81: (200, 0.0001, 0.0001, 128)
# Average RMSE across 5 folds: 0.3974
# Testing combination 61/81: (200, 0.0001, 1e-05, 32)
# Average RMSE across 5 folds: 0.3784
# Testing combination 62/81: (200, 0.0001, 1e-05, 64)
# Average RMSE across 5 folds: 0.4198
# Testing combination 63/81: (200, 0.0001, 1e-05, 128)
# Average RMSE across 5 folds: 0.5091
# Testing combination 64/81: (200, 0.001, 0.001, 32)
# Average RMSE across 5 folds: 0.2841
# Testing combination 65/81: (200, 0.001, 0.001, 64)
# Average RMSE across 5 folds: 0.2877
# Testing combination 66/81: (200, 0.001, 0.001, 128)
# Average RMSE across 5 folds: 0.3093
# Testing combination 67/81: (200, 0.001, 0.0001, 32)
# Average RMSE across 5 folds: 0.3274
# Testing combination 68/81: (200, 0.001, 0.0001, 64)
# Average RMSE across 5 folds: 0.3827
# Testing combination 69/81: (200, 0.001, 0.0001, 128)
# Average RMSE across 5 folds: 0.3950
# Testing combination 70/81: (200, 0.001, 1e-05, 32)
# Average RMSE across 5 folds: 0.3770
# Testing combination 71/81: (200, 0.001, 1e-05, 64)
# Average RMSE across 5 folds: 0.4203
# Testing combination 72/81: (200, 0.001, 1e-05, 128)
# Average RMSE across 5 folds: 0.5117
# Testing combination 73/81: (200, 0.01, 0.001, 32)
# Average RMSE across 5 folds: 0.2825
# Testing combination 74/81: (200, 0.01, 0.001, 64)
# Average RMSE across 5 folds: 0.2866
# Testing combination 75/81: (200, 0.01, 0.001, 128)
# Average RMSE across 5 folds: 0.3057
# Testing combination 76/81: (200, 0.01, 0.0001, 32)
# Average RMSE across 5 folds: 0.3354
# Testing combination 77/81: (200, 0.01, 0.0001, 64)
# Average RMSE across 5 folds: 0.3847
# Testing combination 78/81: (200, 0.01, 0.0001, 128)
# Average RMSE across 5 folds: 0.3927
# Testing combination 79/81: (200, 0.01, 1e-05, 32)
# Average RMSE across 5 folds: 0.3786
# Testing combination 80/81: (200, 0.01, 1e-05, 64)
# Average RMSE across 5 folds: 0.4202
# Testing combination 81/81: (200, 0.01, 1e-05, 128)
# Average RMSE across 5 folds: 0.5083
#
# Tanh Best Hyperparameters: {'hidden_dim': 100, 'lambda_': 0.0001, 'learning_rate': 0.001, 'batch_size': 32}
# Best RMSE: 0.2778

# %%
import itertools
from sklearn.model_selection import KFold
import numpy as np
import torch
from torch import nn

# Define hyperparameter grid
param_grid = {
    'hidden_dim': [50, 100, 200],
    'lambda_': [0.0001, 0.001, 0.01],
    'learning_rate': [0.001, 0.0001, 0.00001],
    'batch_size': [32, 64, 128],
}

param_combinations = list(itertools.product(*param_grid.values()))

# Define K-Fold Cross-Validation
k_folds = 5
kf = KFold(n_splits=k_folds, shuffle=True, random_state=42)

# Function to train and evaluate using K-Fold Cross-Validation
def train_and_evaluate_kfold(params, full_matrix, k_folds):
    # Unpack parameters
    hidden_dim, lambda_, learning_rate, batch_size= params

    # Initialize storage for RMSE scores
    fold_rmse_scores = []

    # Perform K-Fold Cross-Validation
    for train_idx, val_idx in kf.split(full_matrix):
        # Create train and validation matrices
        train_matrix = torch.zeros_like(full_matrix)
        val_matrix = torch.zeros_like(full_matrix)
        
        # Populate train and validation matrices
        train_matrix[train_idx] = full_matrix[train_idx]
        val_matrix[val_idx] = full_matrix[val_idx]
        
        # Initialize model, optimizer, and loss function
        model = AutoRecSig(num_movies, hidden_dim, lambda_).to(device)
        optimizer = torch.optim.Adam(
            model.parameters(),
            lr=learning_rate,
        )
        criterion = nn.MSELoss()

        # Train the model
        train_tensor = train_matrix.to(device)
        val_tensor = val_matrix.to(device)
        for epoch in range(100):  # Fewer epochs for faster cross-validation
            train_epoch(model, train_tensor, optimizer, criterion, batch_size)

            # Evaluate the model on the validation set after each epoch
            val_loss = evaluate_model(model, val_tensor, criterion, batch_size)

        # Final evaluation for this fold
        rmse = calculate_rmse(model, val_tensor, batch_size)
        fold_rmse_scores.append(rmse)

    # Return the average RMSE across all folds
    return np.mean(fold_rmse_scores)

# Track best hyperparameters and performance
best_params = None
best_rmse = float('inf')

# Perform hyperparameter search
for i, params in enumerate(param_combinations):
    print(f"Testing combination {i+1}/{len(param_combinations)}: {params}")
    rmse = train_and_evaluate_kfold(params, user_item_matrix, k_folds)

    print(f"Average RMSE across {k_folds} folds: {rmse:.4f}")

    # Update best parameters if current RMSE is better
    if rmse < best_rmse:
        best_rmse = rmse
        best_params = params

# Print the best hyperparameters
best_param_dict = dict(zip(param_grid.keys(), best_params))
print(f"\nSigmoid Best Hyperparameters: {best_param_dict}")
print(f"Best RMSE: {best_rmse:.4f}")
# Out:
# Testing combination 1/81: (50, 0.0001, 0.001, 32)
# Average RMSE across 5 folds: 0.2520
# Testing combination 2/81: (50, 0.0001, 0.001, 64)
# Average RMSE across 5 folds: 0.2708
# Testing combination 3/81: (50, 0.0001, 0.001, 128)
# Average RMSE across 5 folds: 0.2738
# Testing combination 4/81: (50, 0.0001, 0.0001, 32)
# Average RMSE across 5 folds: 0.2453
# Testing combination 5/81: (50, 0.0001, 0.0001, 64)
# Average RMSE across 5 folds: 0.2509
# Testing combination 6/81: (50, 0.0001, 0.0001, 128)
# Average RMSE across 5 folds: 0.2960
# Testing combination 7/81: (50, 0.0001, 1e-05, 32)
# Average RMSE across 5 folds: 0.5252
# Testing combination 8/81: (50, 0.0001, 1e-05, 64)
# Average RMSE across 5 folds: 0.6361
# Testing combination 9/81: (50, 0.0001, 1e-05, 128)
# Average RMSE across 5 folds: 0.6970
# Testing combination 10/81: (50, 0.001, 0.001, 32)
# Average RMSE across 5 folds: 0.2425
# Testing combination 11/81: (50, 0.001, 0.001, 64)
# Average RMSE across 5 folds: 0.2452
# Testing combination 12/81: (50, 0.001, 0.001, 128)
# Average RMSE across 5 folds: 0.2490
# Testing combination 13/81: (50, 0.001, 0.0001, 32)
# Average RMSE across 5 folds: 0.2425
# Testing combination 14/81: (50, 0.001, 0.0001, 64)
# Average RMSE across 5 folds: 0.2511
# Testing combination 15/81: (50, 0.001, 0.0001, 128)
# Average RMSE across 5 folds: 0.2955
# Testing combination 16/81: (50, 0.001, 1e-05, 32)
# Average RMSE across 5 folds: 0.5259
# Testing combination 17/81: (50, 0.001, 1e-05, 64)
# Average RMSE across 5 folds: 0.6356
# Testing combination 18/81: (50, 0.001, 1e-05, 128)
# Average RMSE across 5 folds: 0.6973
# Testing combination 19/81: (50, 0.01, 0.001, 32)
# Average RMSE across 5 folds: 0.2806
# Testing combination 20/81: (50, 0.01, 0.001, 64)
# Average RMSE across 5 folds: 0.2835
# Testing combination 21/81: (50, 0.01, 0.001, 128)
# Average RMSE across 5 folds: 0.2828
# Testing combination 22/81: (50, 0.01, 0.0001, 32)
# Average RMSE across 5 folds: 0.2561
# Testing combination 23/81: (50, 0.01, 0.0001, 64)
# Average RMSE across 5 folds: 0.2626
# Testing combination 24/81: (50, 0.01, 0.0001, 128)
# Average RMSE across 5 folds: 0.3063
# Testing combination 25/81: (50, 0.01, 1e-05, 32)
# Average RMSE across 5 folds: 0.5257
# Testing combination 26/81: (50, 0.01, 1e-05, 64)
# Average RMSE across 5 folds: 0.6376
# Testing combination 27/81: (50, 0.01, 1e-05, 128)
# Average RMSE across 5 folds: 0.6972
# Testing combination 28/81: (100, 0.0001, 0.001, 32)
# Average RMSE across 5 folds: 0.2522
# Testing combination 29/81: (100, 0.0001, 0.001, 64)
# Average RMSE across 5 folds: 0.2757
# Testing combination 30/81: (100, 0.0001, 0.001, 128)
# Average RMSE across 5 folds: 0.2859
# Testing combination 31/81: (100, 0.0001, 0.0001, 32)
# Average RMSE across 5 folds: 0.2531
# Testing combination 32/81: (100, 0.0001, 0.0001, 64)
# Average RMSE across 5 folds: 0.2493
# Testing combination 33/81: (100, 0.0001, 0.0001, 128)
# Average RMSE across 5 folds: 0.2536
# Testing combination 34/81: (100, 0.0001, 1e-05, 32)
# Average RMSE across 5 folds: 0.3671
# Testing combination 35/81: (100, 0.0001, 1e-05, 64)
# Average RMSE across 5 folds: 0.5099
# Testing combination 36/81: (100, 0.0001, 1e-05, 128)
# Average RMSE across 5 folds: 0.6387
# Testing combination 37/81: (100, 0.001, 0.001, 32)
# Average RMSE across 5 folds: 0.2440
# Testing combination 38/81: (100, 0.001, 0.001, 64)
# Average RMSE across 5 folds: 0.2462
# Testing combination 39/81: (100, 0.001, 0.001, 128)
# Average RMSE across 5 folds: 0.2528
# Testing combination 40/81: (100, 0.001, 0.0001, 32)
# Average RMSE across 5 folds: 0.2462
# Testing combination 41/81: (100, 0.001, 0.0001, 64)
# Average RMSE across 5 folds: 0.2463
# Testing combination 42/81: (100, 0.001, 0.0001, 128)
# Average RMSE across 5 folds: 0.2530
# Testing combination 43/81: (100, 0.001, 1e-05, 32)
# Average RMSE across 5 folds: 0.3671
# Testing combination 44/81: (100, 0.001, 1e-05, 64)
# Average RMSE across 5 folds: 0.5091
# Testing combination 45/81: (100, 0.001, 1e-05, 128)
# Average RMSE across 5 folds: 0.6319
# Testing combination 46/81: (100, 0.01, 0.001, 32)
# Average RMSE across 5 folds: 0.2675
# Testing combination 47/81: (100, 0.01, 0.001, 64)
# Average RMSE across 5 folds: 0.2702
# Testing combination 48/81: (100, 0.01, 0.001, 128)
# Average RMSE across 5 folds: 0.2693
# Testing combination 49/81: (100, 0.01, 0.0001, 32)
# Average RMSE across 5 folds: 0.2483
# Testing combination 50/81: (100, 0.01, 0.0001, 64)
# Average RMSE across 5 folds: 0.2475
# Testing combination 51/81: (100, 0.01, 0.0001, 128)
# Average RMSE across 5 folds: 0.2590
# Testing combination 52/81: (100, 0.01, 1e-05, 32)
# Average RMSE across 5 folds: 0.3686
# Testing combination 53/81: (100, 0.01, 1e-05, 64)
# Average RMSE across 5 folds: 0.5145
# Testing combination 54/81: (100, 0.01, 1e-05, 128)
# Average RMSE across 5 folds: 0.6375
# Testing combination 55/81: (200, 0.0001, 0.001, 32)
# Average RMSE across 5 folds: 0.2590
# Testing combination 56/81: (200, 0.0001, 0.001, 64)
# Average RMSE across 5 folds: 0.2756
# Testing combination 57/81: (200, 0.0001, 0.001, 128)
# Average RMSE across 5 folds: 0.2898
# Testing combination 58/81: (200, 0.0001, 0.0001, 32)
# Average RMSE across 5 folds: 0.2595
# Testing combination 59/81: (200, 0.0001, 0.0001, 64)
# Average RMSE across 5 folds: 0.2578
# Testing combination 60/81: (200, 0.0001, 0.0001, 128)
# Average RMSE across 5 folds: 0.2526
# Testing combination 61/81: (200, 0.0001, 1e-05, 32)
# Average RMSE across 5 folds: 0.2759
# Testing combination 62/81: (200, 0.0001, 1e-05, 64)
# Average RMSE across 5 folds: 0.3575
# Testing combination 63/81: (200, 0.0001, 1e-05, 128)
# Average RMSE across 5 folds: 0.5159
# Testing combination 64/81: (200, 0.001, 0.001, 32)
# Average RMSE across 5 folds: 0.2489
# Testing combination 65/81: (200, 0.001, 0.001, 64)
# Average RMSE across 5 folds: 0.2473
# Testing combination 66/81: (200, 0.001, 0.001, 128)
# Average RMSE across 5 folds: 0.2518
# Testing combination 67/81: (200, 0.001, 0.0001, 32)
# Average RMSE across 5 folds: 0.2477
# Testing combination 68/81: (200, 0.001, 0.0001, 64)
# Average RMSE across 5 folds: 0.2520
# Testing combination 69/81: (200, 0.001, 0.0001, 128)
# Average RMSE across 5 folds: 0.2505
# Testing combination 70/81: (200, 0.001, 1e-05, 32)
# Average RMSE across 5 folds: 0.2755
# Testing combination 71/81: (200, 0.001, 1e-05, 64)
# Average RMSE across 5 folds: 0.3538
# Testing combination 72/81: (200, 0.001, 1e-05, 128)
# Average RMSE across 5 folds: 0.5166
# Testing combination 73/81: (200, 0.01, 0.001, 32)
# Average RMSE across 5 folds: 0.2575
# Testing combination 74/81: (200, 0.01, 0.001, 64)
# Average RMSE across 5 folds: 0.2618
# Testing combination 75/81: (200, 0.01, 0.001, 128)
# Average RMSE across 5 folds: 0.2576
# Testing combination 76/81: (200, 0.01, 0.0001, 32)
# Average RMSE across 5 folds: 0.2445
# Testing combination 77/81: (200, 0.01, 0.0001, 64)
# Average RMSE across 5 folds: 0.2441
# Testing combination 78/81: (200, 0.01, 0.0001, 128)
# Average RMSE across 5 folds: 0.2476
# Testing combination 79/81: (200, 0.01, 1e-05, 32)
# Average RMSE across 5 folds: 0.2772
# Testing combination 80/81: (200, 0.01, 1e-05, 64)
# Average RMSE across 5 folds: 0.3561
# Testing combination 81/81: (200, 0.01, 1e-05, 128)
# Average RMSE across 5 folds: 0.5167
#
# Sigmoid Best Hyperparameters: {'hidden_dim': 50, 'lambda_': 0.001, 'learning_rate': 0.001, 'batch_size': 32}
# Best RMSE: 0.2425
