# %%
import pandas as pd
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
# Load dataset
ratings_path = "ml-latest-small/ratings.csv"
ratings = pd.read_csv(ratings_path)

# %%
# Normalize ratings
min_rating = ratings['rating'].min()
max_rating = ratings['rating'].max()
ratings['normalized_rating'] = ratings['rating'].apply(
    lambda x: (x - min_rating) / (max_rating - min_rating) if x > 0 else 0
)

# %%
# Map userId and movieId to consecutive indices
user_mapping = {user_id: idx for idx, user_id in enumerate(ratings['userId'].unique())}
movie_mapping = {movie_id: idx for idx, movie_id in enumerate(ratings['movieId'].unique())}

# %%
ratings['userId'] = ratings['userId'].map(user_mapping)
ratings['movieId'] = ratings['movieId'].map(movie_mapping)

# Number of users and movies
num_users = len(user_mapping)
num_movies = len(movie_mapping)

# %%
# Create user-item interaction matrix
user_item_matrix = torch.zeros((num_users, num_movies))
for row in ratings.itertuples():
    user_item_matrix[row.userId, row.movieId] = row.normalized_rating

# Transpose the matrix to make it item-user
item_user_matrix = user_item_matrix.T  # Now rows = movies, columns = users

# Split movies into train/validation and test groups
movies = ratings['movieId'].unique()
train_val_movies, test_movies = train_test_split(movies, test_size=0.2, random_state=77)

# %%
# Create train/val and test matrices
train_val_matrix = torch.zeros((len(train_val_movies), num_users))
test_matrix = torch.zeros((len(test_movies), num_users))

# Populate train/val and test matrices
train_val_movie_mapping = {m: i for i, m in enumerate(train_val_movies)}
test_movie_mapping = {m: i for i, m in enumerate(test_movies)}

train_val_data = ratings[ratings['movieId'].isin(train_val_movies)].reset_index(drop=True)
test_data = ratings[ratings['movieId'].isin(test_movies)].reset_index(drop=True)

for row in train_val_data.itertuples():
    movie_idx = train_val_movie_mapping[row.movieId]
    train_val_matrix[movie_idx, row.userId] = row.normalized_rating

for row in test_data.itertuples():
    movie_idx = test_movie_mapping[row.movieId]
    test_matrix[movie_idx, row.userId] = row.normalized_rating

# %%
# Split train/val into separate train and validation matrices
train_matrix, val_matrix = train_test_split(train_val_matrix, test_size=0.2, random_state=78)

# Calculate sparsity
total_entries = num_movies * num_users
non_zero_entries = ratings.shape[0]
sparsity = (1 - (non_zero_entries / total_entries)) * 100
print(f"Item-User Matrix Sparsity: {sparsity:.2f}%")
# Out:
# Item-User Matrix Sparsity: 98.30%

# %%
test_data
# Out:
#        userId  movieId  rating   timestamp  normalized_rating
# 0           0       11     5.0   964981208           1.000000
# 1           0       24     4.0   964980868           0.777778
# 2           0       25     5.0   964981909           1.000000
# 3           0       40     4.0   964982400           0.777778
# 4           0       41     3.0   964982653           0.555556
# ...       ...      ...     ...         ...                ...
# 20012     609     1383     5.0  1479545219           1.000000
# 20013     609     1089     3.5  1493848024           0.666667
# 20014     609     9719     2.5  1479545749           0.444444
# 20015     609     3120     4.0  1493848402           0.777778
# 20016     609     1392     5.0  1493846352           1.000000
#
# [20017 rows x 5 columns]

# %%
# Define models
class AutoRecSig(nn.Module):
    def __init__(self, num_users, hidden_dim, lambda_, p=0.2):
        super(AutoRecSig, self).__init__()
        self.lambda_ = lambda_
        self.encoder = nn.Linear(num_users, hidden_dim, bias=True)
        self.decoder = nn.Linear(hidden_dim, num_users, bias=True)
        self.sigmoid = nn.Sigmoid()
        self.dropout = nn.Dropout(p)

    def forward(self, x):
        encoded = self.dropout(self.sigmoid(self.encoder(x)))
        decoded = self.decoder(encoded)
        return decoded

    def regularization_loss(self):
        reg_loss = 0
        for param in self.parameters():
            reg_loss += param.norm(2)
        return self.lambda_ * reg_loss

# %%
# Training and evaluation functions
def train_epoch(model, train_data, optimizer, criterion, batch_size):
    model.train()
    num_batches = train_data.size(0) // batch_size
    total_loss = 0

    for i in range(num_batches):
        batch = train_data[i * batch_size:(i + 1) * batch_size].to(device)

        optimizer.zero_grad()
        predictions = model(batch)
        mask = batch > 0
        loss = criterion(predictions[mask], batch[mask]) + model.regularization_loss()
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    return total_loss / num_batches

# %%
def evaluate_model(model, test_data, criterion, batch_size):
    model.eval()
    num_batches = test_data.size(0) // batch_size
    total_loss = 0

    with torch.no_grad():
        for i in range(num_batches):
            batch = test_data[i * batch_size:(i + 1) * batch_size].to(device)

            predictions = model(batch)
            mask = batch > 0
            loss = criterion(predictions[mask], batch[mask])
            total_loss += loss.item()

    return total_loss / num_batches

# %%
# Hyperparameters
hidden_dim = 10
lambda_ = 0.001
learning_rate = 0.0001
batch_size = 16
epochs = 50
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Initialize model, optimizer, and loss function
model = AutoRecSig(num_users, hidden_dim, lambda_).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=5e-4)
criterion = nn.MSELoss()

# %%
# Convert matrices to device tensors
train_tensor = train_matrix.to(device)
val_tensor = val_matrix.to(device)
test_tensor = test_matrix.to(device)

# Training loop
train_losses, val_losses = [], []
for epoch in range(epochs):
    train_loss = train_epoch(model, train_tensor, optimizer, criterion, batch_size)
    val_loss = evaluate_model(model, val_tensor, criterion, batch_size)

    train_losses.append(train_loss)
    val_losses.append(val_loss)

    print(f"Epoch {epoch + 1}/{epochs}, Train Loss: {train_loss:.4f}, Validation Loss: {val_loss:.4f}")

# Test the model
test_loss = evaluate_model(model, test_tensor, criterion, batch_size)
print(f"Test Loss: {test_loss:.4f}")
# Out:
# Epoch 1/50, Train Loss: 0.5874, Validation Loss: 0.4702
# Epoch 2/50, Train Loss: 0.4683, Validation Loss: 0.3752
# Epoch 3/50, Train Loss: 0.3781, Validation Loss: 0.2936
# Epoch 4/50, Train Loss: 0.3051, Validation Loss: 0.2252
# Epoch 5/50, Train Loss: 0.2462, Validation Loss: 0.1727
# Epoch 6/50, Train Loss: 0.2012, Validation Loss: 0.1350
# Epoch 7/50, Train Loss: 0.1717, Validation Loss: 0.1086
# Epoch 8/50, Train Loss: 0.1468, Validation Loss: 0.0902
# Epoch 9/50, Train Loss: 0.1324, Validation Loss: 0.0768
# Epoch 10/50, Train Loss: 0.1179, Validation Loss: 0.0682
# Epoch 11/50, Train Loss: 0.1090, Validation Loss: 0.0617
# Epoch 12/50, Train Loss: 0.1022, Validation Loss: 0.0568
# Epoch 13/50, Train Loss: 0.0969, Validation Loss: 0.0534
# Epoch 14/50, Train Loss: 0.0928, Validation Loss: 0.0507
# Epoch 15/50, Train Loss: 0.0891, Validation Loss: 0.0484
# Epoch 16/50, Train Loss: 0.0849, Validation Loss: 0.0465
# Epoch 17/50, Train Loss: 0.0831, Validation Loss: 0.0451
# Epoch 18/50, Train Loss: 0.0792, Validation Loss: 0.0444
# Epoch 19/50, Train Loss: 0.0778, Validation Loss: 0.0430
# Epoch 20/50, Train Loss: 0.0762, Validation Loss: 0.0421
# Epoch 21/50, Train Loss: 0.0747, Validation Loss: 0.0418
# Epoch 22/50, Train Loss: 0.0734, Validation Loss: 0.0412
# Epoch 23/50, Train Loss: 0.0719, Validation Loss: 0.0405
# Epoch 24/50, Train Loss: 0.0715, Validation Loss: 0.0405
# Epoch 25/50, Train Loss: 0.0682, Validation Loss: 0.0405
# Epoch 26/50, Train Loss: 0.0675, Validation Loss: 0.0401
# Epoch 27/50, Train Loss: 0.0666, Validation Loss: 0.0397
# Epoch 28/50, Train Loss: 0.0660, Validation Loss: 0.0395
# Epoch 29/50, Train Loss: 0.0662, Validation Loss: 0.0394
# Epoch 30/50, Train Loss: 0.0654, Validation Loss: 0.0393
# Epoch 31/50, Train Loss: 0.0636, Validation Loss: 0.0395
# Epoch 32/50, Train Loss: 0.0638, Validation Loss: 0.0389
# Epoch 33/50, Train Loss: 0.0633, Validation Loss: 0.0389
# Epoch 34/50, Train Loss: 0.0629, Validation Loss: 0.0391
# Epoch 35/50, Train Loss: 0.0621, Validation Loss: 0.0391
# Epoch 36/50, Train Loss: 0.0615, Validation Loss: 0.0389
# Epoch 37/50, Train Loss: 0.0609, Validation Loss: 0.0390
# Epoch 38/50, Train Loss: 0.0606, Validation Loss: 0.0386
# Epoch 39/50, Train Loss: 0.0598, Validation Loss: 0.0388
# Epoch 40/50, Train Loss: 0.0610, Validation Loss: 0.0384
# Epoch 41/50, Train Loss: 0.0603, Validation Loss: 0.0385
# Epoch 42/50, Train Loss: 0.0600, Validation Loss: 0.0385
# Epoch 43/50, Train Loss: 0.0593, Validation Loss: 0.0384
# Epoch 44/50, Train Loss: 0.0587, Validation Loss: 0.0385
# Epoch 45/50, Train Loss: 0.0583, Validation Loss: 0.0388
# Epoch 46/50, Train Loss: 0.0588, Validation Loss: 0.0386
# Epoch 47/50, Train Loss: 0.0579, Validation Loss: 0.0386
# Epoch 48/50, Train Loss: 0.0587, Validation Loss: 0.0386
# Epoch 49/50, Train Loss: 0.0577, Validation Loss: 0.0386
# Epoch 50/50, Train Loss: 0.0578, Validation Loss: 0.0385
# Test Loss: 0.0388

# %%
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Testing Loss')
plt.show()

# %%
import pandas as pd
import torch
import numpy as np
import math
from torch import nn

# Evaluation Metrics Functions

def calculate_rmse(model, data, batch_size, device):
    model.eval()
    num_batches = data.size(0) // batch_size
    mse = 0
    total_ratings = 0

    with torch.no_grad():
        for i in range(num_batches):
            batch = data[i * batch_size:(i + 1) * batch_size].to(device)
            predictions = model(batch)
            mask = batch > 0

            mse += ((predictions[mask] - batch[mask]) ** 2).sum().item()
            total_ratings += mask.sum().item()

    return np.sqrt(mse / total_ratings)


def calculate_mae(model, data, batch_size, device):
    model.eval()
    num_batches = data.size(0) // batch_size
    mae = 0
    total_ratings = 0

    with torch.no_grad():
        for i in range(num_batches):
            batch = data[i * batch_size:(i + 1) * batch_size].to(device)
            predictions = model(batch)
            mask = batch > 0

            mae += (predictions[mask] - batch[mask]).abs().sum().item()
            total_ratings += mask.sum().item()

    return mae / total_ratings


def calculate_r2(model, data, batch_size, device):
    model.eval()
    num_batches = data.size(0) // batch_size
    ss_total = 0
    ss_residual = 0

    with torch.no_grad():
        for i in range(num_batches):
            batch = data[i * batch_size:(i + 1) * batch_size].to(device)
            predictions = model(batch)
            mask = batch > 0

            mean_rating = batch[mask].mean().item()
            ss_total += ((batch[mask] - mean_rating) ** 2).sum().item()
            ss_residual += ((predictions[mask] - batch[mask]) ** 2).sum().item()

    return 1 - (ss_residual / ss_total)


def evaluate_metrics(model, test_matrix, test_user_mapping, k=10, device="cpu"):
    hr, ndcg, precision, recall, mrr = 0, 0, 0, 0, 0
    total_users = 0

    model.eval()  # Ensure the model is in evaluation mode
    with torch.no_grad():
        for user_id, user_idx in test_user_mapping.items():
            user_ratings = test_matrix[user_idx].to(device)
            ground_truth = torch.nonzero(user_ratings > 0, as_tuple=True)[0].tolist()

            if not ground_truth:
                continue

            predictions = model(user_ratings.unsqueeze(0)).squeeze(0).cpu()
            top_k = min(k, len(predictions))
            predicted_top_k = torch.argsort(predictions, descending=True)[:top_k].tolist()

            hits = len(set(ground_truth) & set(predicted_top_k))

            hr += 1 if hits > 0 else 0
            precision += hits / top_k
            recall += hits / len(ground_truth)

            dcg = sum(
                1 / math.log2(i + 2) if predicted_top_k[i] in ground_truth else 0
                for i in range(top_k)
            )
            idcg = sum(1 / math.log2(i + 2) for i in range(min(len(ground_truth), top_k)))
            ndcg += dcg / idcg if idcg > 0 else 0

            for rank, item in enumerate(predicted_top_k):
                if item in ground_truth:
                    mrr += 1 / (rank + 1)
                    break

            total_users += 1

    if total_users == 0:
        return {"HR": 0, "NDCG": 0, "Precision": 0, "Recall": 0, "MRR": 0}

    return {
        "HR": (hr / total_users) * 100,
        "NDCG": (ndcg / total_users) * 100,
        "Precision": (precision / total_users) * 100,
        "Recall": (recall / total_users) * 100,
        "MRR": (mrr / total_users) * 100,
    }

# %%
# Generate predictions and Print Top-K Movies
def print_top_k_movies_with_titles(
    ratings, user_mapping, movie_mapping, predictions, k, movies_path
):
    movies = pd.read_csv(movies_path)
    reverse_movie_mapping = {v: k for k, v in movie_mapping.items()}
    movie_id_to_title = {row["movieId"]: row["title"] for _, row in movies.iterrows()}

    for user_id in range(predictions.shape[0]):
        actual_movies = (
            ratings[ratings["userId"] == user_id]
            .nlargest(k, "rating")["movieId"]
            .values
        )
        actual_titles = [
            movie_id_to_title.get(reverse_movie_mapping.get(movie), "Unknown")
            for movie in actual_movies
        ]

        predicted_scores = predictions[user_id].cpu().numpy()
        top_k_indices = np.argsort(predicted_scores)[-k:][::-1]
        predicted_movies = [reverse_movie_mapping[idx] for idx in top_k_indices]
        predicted_titles = [movie_id_to_title.get(movie, "Unknown") for movie in predicted_movies]

        print(f"User {user_id + 1}:")
        print(f"  Actual Top Movies: {actual_titles}")
        print(f"  Predicted Top Movies: {predicted_titles}")
        print("----------------------------------------")

# %%
# Metrics and Results
batch_size = 32
rmse = calculate_rmse(model, test_tensor, batch_size, device)
mae = calculate_mae(model, test_tensor, batch_size, device)
r2 = calculate_r2(model, test_tensor, batch_size, device)
# Create a mapping for test movies (for item-based AutoRec)
test_movie_mapping = {m: i for i, m in enumerate(test_movies)}

# Call evaluate_metrics with the correct mapping
k = 10
metrics = evaluate_metrics(model, test_matrix, test_movie_mapping, k=k, device=device)

# Print results
print(f"Test RMSE: {rmse:.4f}")
print(f"Test MAE: {mae:.4f}")
print(f"Test R2: {r2:.4f}")
print(f"Hit Ratio-{k}: {metrics['HR']:.2f}%")
print(f"NDCG-{k}: {metrics['NDCG']:.2f}%")
print(f"Precision-{k}: {metrics['Precision']:.2f}%")
print(f"Recall-{k}: {metrics['Recall']:.2f}%")
print(f"MRR: {metrics['MRR']:.2f}%")
# Out:
# Test RMSE: 0.1972
# Test MAE: 0.1559
# Test R2: 0.1807
# Hit Ratio-10: 16.47%
# NDCG-10: 3.06%
# Precision-10: 2.15%
# Recall-10: 3.61%
# MRR: 4.81%

# %%
# Top-K Movies
with torch.no_grad():
    predictions = model(test_matrix)
print_top_k_movies_with_titles(
    ratings, user_mapping, movie_mapping, predictions, k=5, movies_path="ml-latest-small/movies.csv"
)
# Out:
# User 1:
#   Actual Top Movies: ['Seven (a.k.a. Se7en) (1995)', 'Usual Suspects, The (1995)', 'Bottle Rocket (1996)', 'Rob Roy (1995)', 'Canadian Bacon (1995)']
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Scarlet Letter, The (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)']
# ----------------------------------------
# User 2:
#   Actual Top Movies: ['Step Brothers (2008)', 'Inside Job (2010)', 'Warrior (2011)', 'Wolf of Wall Street, The (2013)', 'Mad Max: Fury Road (2015)']
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 3:
#   Actual Top Movies: ['Escape from L.A. (1996)', 'Saturn 3 (1980)', 'Road Warrior, The (Mad Max 2) (1981)', 'The Lair of the White Worm (1988)', 'Hangar 18 (1980)']
#   Predicted Top Movies: ['Independence Day (a.k.a. ID4) (1996)', 'Stuart Saves His Family (1995)', 'Scarlet Letter, The (1995)', 'Only You (1994)', 'Toy Story (1995)']
# ----------------------------------------
# User 4:
#   Actual Top Movies: ['Flirting With Disaster (1996)', 'Crumb (1994)', 'Living in Oblivion (1995)', 'Before Sunrise (1995)', 'Eat Drink Man Woman (Yin shi nan nu) (1994)']
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 5:
#   Actual Top Movies: ['Postman, The (Postino, Il) (1994)', 'Heavenly Creatures (1994)', 'Once Were Warriors (1994)', 'Pulp Fiction (1994)', 'In the Name of the Father (1993)']
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 6:
#   Actual Top Movies: ['Grumpier Old Men (1995)', 'Father of the Bride Part II (1995)', 'Copycat (1995)', 'Dead Man Walking (1995)', 'White Squall (1996)']
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Scarlet Letter, The (1995)']
# ----------------------------------------
# User 7:
#   Actual Top Movies: ['Star Wars: Episode IV - A New Hope (1977)', 'Forrest Gump (1994)', 'Hot Shots! Part Deux (1993)', 'Jurassic Park (1993)', 'Silence of the Lambs, The (1991)']
#   Predicted Top Movies: ['Independence Day (a.k.a. ID4) (1996)', 'Stuart Saves His Family (1995)', 'Scarlet Letter, The (1995)', 'Only You (1994)', 'Down Periscope (1996)']
# ----------------------------------------
# User 8:
#   Actual Top Movies: ['Babe (1995)', 'Usual Suspects, The (1995)', 'Net, The (1995)', 'Interview with the Vampire: The Vampire Chronicles (1994)', 'Shawshank Redemption, The (1994)']
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 9:
#   Actual Top Movies: ['Citizen Kane (1941)', 'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)', 'Back to the Future (1985)', 'Producers, The (1968)', 'Lord of the Rings: The Fellowship of the Ring, The (2001)']
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Scarlet Letter, The (1995)']
# ----------------------------------------
# User 10:
#   Actual Top Movies: ['Troy (2004)', 'Notebook, The (2004)', 'First Daughter (2004)', 'Batman Begins (2005)', 'Casino Royale (2006)']
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 11:
#   Actual Top Movies: ['Heat (1995)', 'Braveheart (1995)', 'Apollo 13 (1995)', 'Clear and Present Danger (1994)', 'Forrest Gump (1994)']
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User
']
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 51:
#   Actual Top Movies: ['From Dusk Till Dawn (1996)', 'Screamers (1995)', 'Taxi Driver (1976)', 'French Kiss (1995)', 'Heavenly Creatures (1994)']
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 52:
#   Actual Top Movies: ['Shawshank Redemption, The (1994)', 'Forrest Gump (1994)', 'Lion King, The (1994)', 'Aladdin (1992)', 'Rock, The (1996)']
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 53:
#   Actual Top Movies: ['To Wong Foo, Thanks for Everything! Julie Newmar (1995)', 'Immortal Beloved (1994)', 'When a Man Loves a Woman (1994)', 'Airheads (1994)', 'Kalifornia (1993)']
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 54:
#   Actual Top Movies: ['Shawshank Redemption, The (1994)', 'Forrest Gump (1994)', 'Silence of the Lambs, The (1991)', 'Toy Story (1995)', 'Sense and Sensibility (1995)']
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 55:
#   Actual Top Movies: ['Lock, Stock & Two Smoking Barrels (1998)', 'Boondock Saints, The (2000)', 'Snatch (2000)', 'Layer Cake (2004)', 'Departed, The (2006)']
#   Predicted Top Movies: ['Independence Day (a.k.a. ID4) (1996)', 'Stuart Saves His Family (1995)', 'Scarlet Letter, The (1995)', 'Only You (1994)', 'Toy Story (1995)']
# ----------------------------------------
# User 56:
#   Actual Top Movies: ['Ace Ventura: When Nature Calls (1995)', 'Seven (a.k.a. Se7en) (1995)', 'Dumb & Dumber (Dumb and Dumber) (1994)', 'Ace Ventura: Pet Detective (1994)', 'Forrest Gump (1994)']
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 57:
#   Actual Top Movies: ['Toy Story (1995)', 'Usual Suspects, The (1995)', 'Ed Wood (1994)', 'Star Wars: Episode IV - A New Hope (1977)', 'Fugitive, The (1993)']
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 58:
#   Actual Top Movies: ['Sabrina (1995)', 'Twelve Monkeys (a.k.a. 12 Monkeys) (1995)', 'Clueless (1995)', 'Seven (a.k.a. Se7en) (1995)', 'Usual Suspects, The (1995)']
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 59:
#   Actual Top Movies: ['Richard III (1995)', 'Taxi Driver (1976)', "Schindler's List (1993)", 'Blade Runner (1982)', 'Silence of the Lambs, The (1991)']
#   Predicted Top Movies: ['Independence Day (a.k.a. ID4) (1996)', 'Stuart Saves His Family (1995)', 'Scarlet Letter, The (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Toy Story (1995)']
# ----------------------------------------
# User 60:
#   Actual Top Movies: ["Schindler's List (1993)", 'Godfather, The (1972)', 'Dark Knight, The (2008)', 'Shawshank Redemption, The (1994)', 'Jungle Book, The (1994)']
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 61:
#   Actual Top Movies: ['Shawshank Redemption, The (1994)', 'Butch Cassidy and the Sundance Kid (1969)', 'Twelve Monkeys (a.k.a. 12 Monkeys) (1995)', 'Usual Suspects, The (1995)', 'Léon: The Professional (a.k.a. The Professional) (Léon) (1994)']
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 62:
#   Actual Top Movies: ['Léon: The Professional (a.k.a. The Professional) (Léon) (1994)', 'Forrest Gump (1994)', 'Silence of the Lambs, The (1991)', 'Godfather, The (1972)', 'Reservoir Dogs (1992)']
#   Predicted Top Movies: ['Independence Day (a.k.a. ID4) (1996)', 'Stuart Saves His Family (1995)', 'Scarlet Letter, The (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Toy Story (1995)']
# ----------------------------------------
# User 63:
#   Actual Top Movies: ['Toy Story (1995)', 'Usual Suspects, The (1995)', 'Star Wars: Episode IV - A New Hope (1977)', 'Pulp Fiction (1994)', 'Shawshank Redemption, The (1994)']
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 64:
#   Actual Top Movies: ['Casino (1995)', 'Legends of the Fall (1994)', 'Shawshank Redemption, The (1994)', "Schindler's List (1993)", 'Dances with Wolves (1990)']
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Scarlet Letter, The (1995)']
# ----------------------------------------
# User 65:
#   Actual Top Movies: ['Into the Wild (2007)', 'Truman Show, The (1998)', 'American History X (1998)', 'Fight Club (1999)', 'Green Mile, The (1999)']
#   Predicted Top Movies: ['Independence Day (a.k.a. ID4) (1996)', 'Stuart Saves His Family (1995)', 'Scarlet Letter, The (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Toy Story (1995)']
# ----------------------------------------
# User 66:
#   Actual Top Movies: ['Twelve Monkeys (a.k.a. 12 Monkeys) (1995)', 'Seven (a.k.a. Se7en) (1995)', 'Braveheart (1995)', 'Don Juan DeMarco (1995)', 'Pulp Fiction (1994)']
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 67:
#   Actual Top Movies: ['Léon: The Professional (a.k.a. The Professional) (Léon) (1994)', 'Fifth Element, The (1997)', 'Taxi (1998)', 'Taxi 2 (2000)', 'Pulp Fiction (1994)']
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 68:
#   Actual Top Movies: ['Star Wars: Episode IV - A New Hope (1977)', 'Speed (1994)', 'Gone with the Wind (1939)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Princess Bride, The (1987)']
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 69:
#   Actual Top Movies: ['Usual Suspects, The (1995)', 'Star Wars: Episode IV - A New Hope (1977)', 'Pulp Fiction (1994)', 'Shawshank Redemption, The (1994)', 'Tommy Boy (1995)']
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 70:
#   Actual Top Movies: ['Dead Man Walking (1995)', "Schindler's List (1993)", 'Godfather, The (1972)', "It's a Wonderful Life (1946)", 'Cinema Paradiso (Nuovo cinema Paradiso) (1989)']
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 71:
#   Actual Top Movies: ['Toy Story (1995)', 'White Squall (1996)', 'Die Hard: With a Vengeance (1995)', 'Twister (1996)', 'Independence Day (a.k.a. ID4) (1996)']
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 72:
#   Actual Top Movies: ['Star Wars: Episode IV - A New Hope (1977)', 'Shawshank Redemption, The (1994)', 'Matrix, The (1999)', "Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001)", 'Twelve Monkeys (a.k.a. 12 Monkeys) (1995)']
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User
1994)']
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 91:
#   Actual Top Movies: ['Heat (1995)', 'Desperado (1995)', 'Crow, The (1994)', 'Blade Runner (1982)', 'Nightmare Before Christmas, The (1993)']
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 92:
#   Actual Top Movies: ['Muppet Treasure Island (1996)', 'Matilda (1996)', '10 Things I Hate About You (1999)', 'Peter Pan (1953)', 'Easy Rider (1969)']
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 93:
#   Actual Top Movies: ['Jumanji (1995)', 'Babe (1995)', 'Braveheart (1995)', 'Apollo 13 (1995)', 'Star Wars: Episode IV - A New Hope (1977)']
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 94:
#   Actual Top Movies: ['Twelve Monkeys (a.k.a. 12 Monkeys) (1995)', 'Braveheart (1995)', 'Shawshank Redemption, The (1994)', 'Jumanji (1995)', 'Babe (1995)']
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 95:
#   Actual Top Movies: ['Leaving Las Vegas (1995)', 'City of Lost Children, The (Cité des enfants perdus, La) (1995)', 'Crumb (1994)', 'Star Wars: Episode IV - A New Hope (1977)', 'Blade Runner (1982)']
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 96:
#   Actual Top Movies: ['Toy Story (1995)', 'Babe (1995)', 'Usual Suspects, The (1995)', 'Braveheart (1995)', 'Apollo 13 (1995)']
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 97:
#   Actual Top Movies: ['Silence of the Lambs, The (1991)', 'Godfather, The (1972)', 'Star Wars: Episode VI - Return of the Jedi (1983)', 'Saving Private Ryan (1998)', 'Matrix, The (1999)']
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 98:
#   Actual Top Movies: ['Forrest Gump (1994)', 'Rear Window (1954)', 'Die Hard (1988)', 'Princess Bride, The (1987)', 'Psycho (1960)']
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 99:
#   Actual Top Movies: ['Apollo 13 (1995)', 'Batman Forever (1995)', 'Desperado (1995)', 'Die Hard: With a Vengeance (1995)', 'First Knight (1995)']
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 100:
#   Actual Top Movies: ['Top Gun (1986)', 'Terms of Endearment (1983)', "Christmas Vacation (National Lampoon's Christmas Vacation) (1989)", 'Officer and a Gentleman, An (1982)', 'Sweet Home Alabama (2002)']
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 101:
#   Actual Top Movies: ['Doors, The (1991)', 'Sweet Hereafter, The (1997)', 'Happiness (1998)', 'Rushmore (1998)', 'Election (1999)']
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 102:
#   Actual Top Movies: ['Grumpier Old Men (1995)', 'Seven (a.k.a. Se7en) (1995)', 'Clerks (1994)', 'Pulp Fiction (1994)', 'Forrest Gump (1994)']
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 103:
#   Actual Top Movies: ['Casino (1995)', 'Four Rooms (1995)', 'Pulp Fiction (1994)', 'Shawshank Redemption, The (1994)', 'True Romance (1993)']
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 104:
#   Actual Top Movies: ['Four Weddings and a Funeral (1994)', 'Beauty and the Beast (1991)', 'Wallace & Gromit: A Close Shave (1995)', 'Wallace & Gromit: The Wrong Trousers (1993)', '10 Things I Hate About You (1999)']
#   Predicted Top Movies: ['Independence Day (a.k.a. ID4) (1996)', 'Stuart Saves His Family (1995)', 'Scarlet Letter, The (1995)', 'Only You (1994)', 'Saving Private Ryan (1998)']
# ----------------------------------------
# User 105:
#   Actual Top Movies: ['Seven (a.k.a. Se7en) (1995)', 'Usual Suspects, The (1995)', 'Léon: The Professional (a.k.a. The Professional) (Léon) (1994)', 'Pulp Fiction (1994)', 'Three Colors: Red (Trois couleurs: Rouge) (1994)']
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 106:
#   Actual Top Movies: ['Shawshank Redemption, The (1994)', 'Matrix, The (1999)', "Harry Potter and the Sorcerer's Stone (a.k.a. Harry Potter and the Philosopher's Stone) (2001)", 'Lord of the Rings: The Fellowship of the Ring, The (2001)', 'Lord of the Rings: The Two Towers, The (2002)']
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 107:
#   Actual Top Movies: ['Jumanji (1995)', 'American President, The (1995)', "Mr. Holland's Opus (1995)", 'Braveheart (1995)', 'Birdcage, The (1996)']
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 108:
#   Actual Top Movies: ["Antonia's Line (Antonia) (1995)", 'Piano, The (1993)', 'Blade Runner (1982)', 'Lone Star (1996)', 'Emma (1996)']
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 109:
#   Actual Top Movies: ['Leaving Las Vegas (1995)', 'Dead Man Walking (1995)', "Mr. Holland's Opus (1995)", 'Braveheart (1995)', 'Kids (1995)']
#   Predicted Top Movies: ['Independence Day (a.k.a. ID4) (1996)', 'Stuart Saves His Family (1995)', 'Scarlet Letter, The (1995)', 'Only You (1994)', 'Divided We Fall (Musíme si pomáhat) (2000)']
# ----------------------------------------
# User 110:
#   Actual Top Movies: ['Cool Hand Luke (1967)', "Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001)", 'Rivers and Tides (2001)', 'Play Time (a.k.a. Playtime) (1967)', 'Seven (a.k.a. Se7en) (1995)']
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 111:
#   Actual Top Movies: ['Forrest Gump (1994)', 'Fight Club (1999)', 'Dogma (1999)', "Wayne's World (1992)", 'Boondock Saints, The (2000)']
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 112:
#   Actual Top Movies: ['Twelve Monkeys (a.k.a. 12 Monkeys) (1995)', 'Seven (a.k.a. Se7en) (1995)', 'Usual Suspects, The (1995)', 'Star Wars: Episode IV - A New Hope (1977)', 'Jurassic Park (1993)']
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 113:
#   Actual Top Movies: ['Like Water for Chocolate (Como agua para chocolate) (1992)', 'Léon: The Professional (a.k.a. The Professional) (Léon) (1994)', 'Corrina, Corrina (1994)', 'Piano, The (1993)', "Breakfast at Tiffany's (1961)"]
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 114:
#   Actual Top Movies: ['Deathgasm (2015)', 'Spider-Man 2 (2004)', 'Spider-Man 3 (2007)', 'Wolf of Wall Street, The (2013)', 'Edward Scissorhands (1990)']
#   Predicted Top Movies: ['Independence Day (a.k.a. ID4) (1996)', 'Stuart Saves His Family (1995)', 'Scarlet Letter, The (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Toy Story (1995)']
# ----------------------------------------
# User 115:
#   Actual Top Movies: ['Twelve Monkeys (a.k.a. 12 Monkeys) (1995)', 'Star Wars: Episode IV - A New Hope (1977)', 'Pulp Fiction (1994)', 'Jurassic Park (1993)', 'Lightning Jack (1994)']
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 116:
#   Actual Top Movies: ['Mask, The (1994)', 'Blade Runner (1982)', 'Sound of Music, The (1965)', 'Top Gun (1986)', 'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)']
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# ...
# User 1886:
#   Actual Top Movies: []
#   Predicted Top Movies: ['Independence Day (a.k.a. ID4) (1996)', 'Stuart Saves His Family (1995)', 'Scarlet Letter, The (1995)', 'Only You (1994)', 'Saving Private Ryan (1998)']
# ----------------------------------------
# User 1887:
#   Actual Top Movies: []
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 1888:
#   Actual Top Movies: []
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 1889:
#   Actual Top Movies: []
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 1890:
#   Actual Top Movies: []
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 1891:
#   Actual Top Movies: []
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 1892:
#   Actual Top Movies: []
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 1893:
#   Actual Top Movies: []
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 1894:
#   Actual Top Movies: []
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 1895:
#   Actual Top Movies: []
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 1896:
#   Actual Top Movies: []
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 1897:
#   Actual Top Movies: []
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Scarlet Letter, The (1995)']
# ----------------------------------------
# User 1898:
#   Actual Top Movies: []
#   Predicted Top Movies: ['Independence Day (a.k.a. ID4) (1996)', 'Stuart Saves His Family (1995)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Scarlet Letter, The (1995)']
# ----------------------------------------
# User 1899:
#   Actual Top Movies: []
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 1900:
#   Actual Top Movies: []
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 1901:
#   Actual Top Movies: []
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Scarlet Letter, The (1995)']
# ----------------------------------------
# User 1902:
#   Actual Top Movies: []
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 1903:
#   Actual Top Movies: []
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 1904:
#   Actual Top Movies: []
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 1905:
#   Actual Top Movies: []
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 1906:
#   Actual Top Movies: []
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 1907:
#   Actual Top Movies: []
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 1908:
#   Actual Top Movies: []
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 1909:
#   Actual Top Movies: []
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 1910:
#   Actual Top Movies: []
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 1911:
#   Actual Top Movies: []
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 1912:
#   Actual Top Movies: []
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 1913:
#   Actual Top Movies: []
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 1914:
#   Actual Top Movies: []
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 1915:
#   Actual Top Movies: []
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 1916:
#   Actual Top Movies: []
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 1917:
#   Actual Top Movies: []
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Scarlet Letter, The (1995)']
# ----------------------------------------
# User 1918:
#   Actual Top Movies: []
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 1919:
#   Actual Top Movies: []
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 1920:
#   Actual Top Movies: []
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 1921:
#   Actual Top Movies: []
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 1922:
#   Actual Top Movies: []
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Scarlet Letter, The (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Only You (1994)']
# ----------------------------------------
# User 1923:
#   Actual Top Movies: []
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 1924:
#   Actual Top Movies: []
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 1925:
#   Actual Top Movies: []
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 1926:
#   Actual Top Movies: []
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 1927:
#   Actual Top Movies: []
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Scarlet Letter, The (1995)']
# ----------------------------------------
# User 1928:
#   Actual Top Movies: []
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 1929:
#   Actual Top Movies: []
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Scarlet Letter, The (1995)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)']
# ----------------------------------------
# User 1930:
#   Actual Top Movies: []
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 1931:
#   Actual Top Movies: []
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 1932:
#   Actual Top Movies: []
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 1933:
#   Actual Top Movies: []
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 1934:
#   Actual Top Movies: []
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 1935:
#   Actual Top Movies: []
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 1936:
#   Actual Top Movies: []
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 1937:
#   Actual Top Movies: []
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 1938:
#   Actual Top Movies: []
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 1939:
#   Actual Top Movies: []
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 1940:
#   Actual Top Movies: []
#   Predicted Top Movies: ['Independence Day (a.k.a. ID4) (1996)', 'Stuart Saves His Family (1995)', 'Toy Story (1995)', 'Scarlet Letter, The (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)']
# ----------------------------------------
# User 1941:
#   Actual Top Movies: []
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 1942:
#   Actual Top Movies: []
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 1943:
#   Actual Top Movies: []
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 1944:
#   Actual Top Movies: []
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------
# User 1945:
#   Actual Top Movies: []
#   Predicted Top Movies: ['Stuart Saves His Family (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Toy Story (1995)', 'Divided We Fall (Musíme si pomáhat) (2000)', 'Down Periscope (1996)']
# ----------------------------------------

# %% [markdown]
# # Choosing hyperparameters

# %%
import itertools
from sklearn.model_selection import KFold
import numpy as np
import torch
from torch import nn

# Define hyperparameter grid
param_grid = {
    'hidden_dim': [10, 25, 50, 100,],
    'lambda_': [0.0001, 0.001, 0.01],
    'learning_rate': [0.001, 0.0001, 0.00001],
    'batch_size': [16, 32, 64],
}

param_combinations = list(itertools.product(*param_grid.values()))

# Define K-Fold Cross-Validation
k_folds = 5
kf = KFold(n_splits=k_folds, shuffle=True, random_state=42)

# Function to train and evaluate using K-Fold Cross-Validation
def train_and_evaluate_kfold(params, full_matrix, k_folds, num_users, num_movies):
    # Unpack parameters
    hidden_dim, lambda_, learning_rate, batch_size = params

    # Initialize storage for RMSE scores
    fold_rmse_scores = []

    # Perform K-Fold Cross-Validation
    for train_idx, val_idx in kf.split(np.arange(full_matrix.size(0))):  # Split over items
        # Create train and validation matrices
        train_matrix = torch.zeros_like(full_matrix)
        val_matrix = torch.zeros_like(full_matrix)

        # Populate train and validation matrices based on split indices
        train_matrix[train_idx, :] = full_matrix[train_idx, :]
        val_matrix[val_idx, :] = full_matrix[val_idx, :]

        # Initialize model, optimizer, and loss function
        model = AutoRecSig(num_users, hidden_dim, lambda_).to(device)
        optimizer = torch.optim.Adam(
            model.parameters(),
            lr=learning_rate,
        )
        criterion = nn.MSELoss()

        # Train the model
        train_tensor = train_matrix.to(device)
        val_tensor = val_matrix.to(device)
        for epoch in range(50):  # Reduced epochs for faster cross-validation
            train_epoch(model, train_tensor, optimizer, criterion, batch_size)

            # Evaluate the model on the validation set after each epoch
            val_loss = evaluate_model(model, val_tensor, criterion, batch_size)

        # Final evaluation for this fold
        rmse = calculate_rmse(model, val_tensor, batch_size, device)
        fold_rmse_scores.append(rmse)

    # Return the average RMSE across all folds
    return np.mean(fold_rmse_scores)

# Track best hyperparameters and performance
best_params = None
best_rmse = float('inf')

# Perform hyperparameter search
for i, params in enumerate(param_combinations):
    print(f"Testing combination {i+1}/{len(param_combinations)}: {params}")
    rmse = train_and_evaluate_kfold(params, item_user_matrix, k_folds, num_users, num_movies)

    print(f"Average RMSE across {k_folds} folds: {rmse:.4f}")

    # Update best parameters if current RMSE is better
    if rmse < best_rmse:
        best_rmse = rmse
        best_params = params

# Print the best hyperparameters
best_param_dict = dict(zip(param_grid.keys(), best_params))
print(f"\nRelU Best Hyperparameters: {best_param_dict}")
print(f"Best RMSE: {best_rmse:.4f}")
# Out:
# Testing combination 1/108: (10, 0.0001, 0.001, 16)
# Average RMSE across 5 folds: 0.1798
# Testing combination 2/108: (10, 0.0001, 0.001, 32)
# Average RMSE across 5 folds: 0.1812
# Testing combination 3/108: (10, 0.0001, 0.001, 64)
# Average RMSE across 5 folds: 0.1842
# Testing combination 4/108: (10, 0.0001, 0.0001, 16)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[63], line 70
#      68 for i, params in enumerate(param_combinations):
#      69     print(f"Testing combination {i+1}/{len(param_combinations)}: {params}")
# ---> 70     rmse = train_and_evaluate_kfold(params, item_user_matrix, k_folds, num_users, num_movies)
#      72     print(f"Average RMSE across {k_folds} folds: {rmse:.4f}")
#      74     # Update best parameters if current RMSE is better
#
# Cell In[63], line 54, in train_and_evaluate_kfold(params, full_matrix, k_folds, num_users, num_movies)
#      51     train_epoch(model, train_tensor, optimizer, criterion, batch_size)
#      53     # Evaluate the model on the validation set after each epoch
# ---> 54     val_loss = evaluate_model(model, val_tensor, criterion, batch_size)
#      56 # Final evaluation for this fold
#      57 rmse = calculate_rmse(model, val_tensor, batch_size, device)
#
# Cell In[24], line 12, in evaluate_model(model, test_data, criterion, batch_size)
#      10         predictions = model(batch)
#      11         mask = batch > 0
# ---> 12         loss = criterion(predictions[mask], batch[mask])
#      13         total_loss += loss.item()
#      15 return total_loss / num_batches
#
# File ~/Environments/dl/lib/python3.12/site-packages/torch/nn/modules/module.py:1732, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1729             tracing_state.pop_scope()
#    1730     return result
# -> 1732 def _wrapped_call_impl(self, *args, **kwargs):
#    1733     if self._compiled_call_impl is not None:
#    1734         return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#
# KeyboardInterrupt:
